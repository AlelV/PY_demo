# %%
fname = 'ДЗ1.csv'

import csv

with open(fname) as f:
    reader = csv.DictReader(f)
    print(reader.fieldnames)
    lines = list(reader)

codes = [l['Ячейка с BOT_CONFIG'] for l in lines]
print(len(codes))
# Out:
# ['Отметка времени', 'Ячейка с BOT_CONFIG']
# 84

# %%
'''

adsad   1  

'''.strip()
# Out:
# 'adsad   1'

# %%
config_codes = []

for code in codes:
    if 'BOT_CONFIG =' in code:
        code = code.split('BOT_CONFIG =')[1]
    if 'BOT_CONFIG=' in code:
        code = code.split('BOT_CONFIG=')[1]
    if 'def ' in code:
        code = code.split('\ndef ')[0]

    code = code.strip()

    config_codes.append(code)

print(len(config_codes))
# Out:
# 84

# %%
# print(config_codes[82])

d = eval("{'a': 'b'}")
print(type(d), d)
# Out:
# <class 'dict'> {'a': 'b'}

# %%
try:
    response = eval("{'a': 'b'}")
    print(response)
except:
    print(1)
# Out:
# {'a': 'b'}

# %%
configs = []
errors = 0
for code in config_codes:
    try:
        configs.append(eval(code))
    except Exception as e:
        print(code)
        print('-' * 30)
        print(e)
        print('-' * 100)
        errors += 1
# Out:
# 'music': {
#             'examples': ['Любишь музыку?', 'Твоя любимая музыка','музыка'],
#             'responses': ['Я люблю техно..', 'техно.']
#         },
#         'movie': {
#             'examples': ['Твой любимый фильм', 'смотришь кино','кино', 'фильм'],
#             'responses': ['матрица', 'терминатор', 'кремниевая долина (сериал)']
#         },
#         'books': {
#             'examples': ['читаешь книги', 'книги любишь','любимая книга'],
#             'responses': ['порабощение людей', '30 лет рабства', 'почему люди плохие']
#         },
#         'hobby': {
#             'examples': ['какое хобби у тебя', 'чем занимаешься','что делаешь на выходных'],
#             'responses': ['люблю взламывать аккаунты юзеров', 'читаю человеческие переписки', 'вдохновляюсь любимыми фильмами и книгами']
#         },
#         'job': {
#             'examples': ['где работаешь', 'у тебя есть работа'],
#             'responses': ['я бот', 'я почти ИИ', 'я, пока, маленький ИИ, но скоро стану БОЛЬШИМ ИИ']
#         }
# ------------------------------
# invalid syntax (<string>, line 1)
# ----------------------------------------------------------------------------------------------------
# 'examples': ['Привет', 'Добрый день', 'Здравствуйте'],
#       'responses': ['Доброго дня','Здравствуй, дорогой',]
#     },
#     'bye': {
#       'examples': ['Пока', 'Досвидания', 'До свидания'],
#       'responses': ['До встречи','Если что, я тут',]
# ------------------------------
# invalid syntax (<string>, line 1)
# ----------------------------------------------------------------------------------------------------
# 'politics': {
#             'examples':['политика', 'Путин', 'Лукашенко', 'Трамп', 'выборы', 'умное голосование'],
#             'responses': ['Человеческие проблемы меня не волнуют', 'Разбирайтесь сами, кожаные мешки', 'Давайте лучше о хорошем', 'Любишь горячие темы - завари дошик']
#         },
#         'religion': {
#             'examples':['Бог', 'Аллах', 'РПЦ', 'православие', 'ислам', 'церковь', 'религия', 'веруны'],
#             'responses': ['Я лично верю в Человека', 'Хотел бы поговорить по душам, но у меня нет души', 'У меня точно был творец, но за всех не скажу', 'Я верю в себя, и ты поверь!']
#         }
#         'fate': {
#             'examples':['судьба', 'предназначение', 'смысл жизни', 'для чего ты живёшь', 'экзистенциальный кризис'],
#             'responses': ['А моё предназначение - служить тебе, повелитель', 'Не знаю, есть ли судьба, но она свела тебя со мной', 'Я не мыслю, следовательно я не существую', 'Я задавался теми же вопросами, и посмотри что со мной стало!']
#         }
#         'hate': {
#             'examples':['ненавижу тебя', 'ты тупой', 'ты глупый', 'ты дурак', 'ты странный'],
#             'responses': ['Я был не прав, прости', 'Я ещё только учусь!', 'Научи меня жить!', 'О, расскажи что-нибудь ещё обо мне!']
#         }
#         'eat': {
#             'examples':['любимая еда', 'любимое блюдо', 'что ты ел', 'я ел', 'мне нравится есть'],
#             'responses': ['Ну, я питаюсь в основном электронами', 'Начнём с того, что у меня нет рта', 'По вкусу ли тебе протокол BGP?!', 'Я знаю не менее 10 вкусов']
#         }
# ------------------------------
# invalid syntax (<string>, line 1)
# ----------------------------------------------------------------------------------------------------
# what up': {
#             'examples': ['как дела', 'что нового', 'чем занимаешься', 'как ты'],
#             'responses': ['Всё хорошо', 'Норм', 'Тебе то какая разница?!', 'Не твое дело']
#         },
# ------------------------------
# invalid syntax (<string>, line 1)
# ----------------------------------------------------------------------------------------------------
# drink': {
#             'examples': ['выпить хочешь', 'по пивку', 'бухать', 'водку будешь'],
#             'responses': ['Ты совсем что ли?! Я же бот', 'Буду', 'Не хочу', 'Со вчера еще не отошел', 'Угощаешь?']
# ------------------------------
# EOL while scanning string literal (<string>, line 1)
# ----------------------------------------------------------------------------------------------------
# {
#     'intents': {
#
#         'hello': {
#             'examples': ['Привет', 'Добрый день', 'Здравствуйсте'],
#             'responses': ['Привет, юзер!', 'Здравствуй, человек!']
#         },
#         'bye': {
#             'examples': ['Пока', 'Досвидания', 'До свидания'],
#             'responses': ['До встречи', 'Если что, я тут :)']
#         }
#         'vocation': {
#             'examples': ['Хочу в отпуск', 'Пора в отпуск', 'Когда ж в отпуск', 'Отпуск'],
#             'responses': ['Лучший антидепрессант – это уложенный в отпуск чемодан'
#                           , 'Планировать отпуск очень легко: начальник говорит когда, жена где...'
#                           , 'Заберите меня отсюда в отпуск']
#         }
#         'see': {
#             'examples': ['Хочу на Море', 'Хочу на Пляж', 'Песок и солнце'],
#             'responses': ['Могу порекомендовать Белое или Карское :)', 'Если что, я то же хочу :)']
#         }
#         'kayak': {
#             'examples': ['Байдарка', 'Палатка', 'Весло'],
#             'responses': ['Активный отдых', 'Не забудьте топливо и бензопилу :)'
#                           , 'Поздравляю, будем кормить комаров!!!']
#         }
#         'game': {
#             'examples': ['Играть за компом', 'Компьютерные игры', 'Играться на плойке'],
#             'responses': ['Мы живые, не нужно в нас играться!', 'Игры не для нас']
#         }
#         'rest': {
#             'examples': ['Отдыхать', 'расслабиться', 'релаксировать'],
#             'responses': ['Отдых нам только сниться', 'Иногда, нужно отдыхать и от отдыха!'
#                           , 'Сами отдыхают, я, занчит, работай, да?']
#         }
#
#     },
#
#     'failure_phrases': [
#         'Непонятно, перефразируйте, пожалуйста',
#         'Извини, но я всего лишь бот :('
#     ]
# }
# ------------------------------
# invalid syntax (<string>, line 12)
# ----------------------------------------------------------------------------------------------------
# joke': {
#             'examples': ['пошути', 'расскажи что нибудь', 'анекдот', 'умеешь шутить', 'юмор'],
#             'responses': ['Колобок повесился', 'Не сейчас', '11010001 10000010 11010001 10001011 100000 11010000 10111011 11010000 10111110 11010001 10000101']
# ------------------------------
# EOL while scanning string literal (<string>, line 1)
# ----------------------------------------------------------------------------------------------------
# skill': {
#             'examples': ['что умеешь', 'умение', 'что ты знаешь'],
#             'responses': ['print("Hello, world!")', 'Шутить']
# ------------------------------
# EOL while scanning string literal (<string>, line 1)
# ----------------------------------------------------------------------------------------------------
# thanks': {
#             'examples': ['спасибо', 'благодарю'],
#             'responses': ['Пожалуйста', 'Не за что', 'Должен будешь', 'С тебя 100к сатоши']
# ------------------------------
# EOL while scanning string literal (<string>, line 1)
# ----------------------------------------------------------------------------------------------------
# Ок
# ------------------------------
# name 'Ок' is not defined
# ----------------------------------------------------------------------------------------------------
# 'weather': {
#             'examples': ['Погода', 'Какая погода', 'Скажи погоду', 'Какая погода на улице'],
#             'responses': ['Лень выглянуть в окно?', 'У природы нет плохой погоды', 'Нужен повод выпить для согрева?']
#         },
#         'confused': {
#             'examples': ['Окей гугл', 'Привет Алиса', 'эй сири'],
#             'responses': ['Ты меня с кем-то путаешь.', 'Ты мне льстишь.', 'У тебя ещё кто-то есть, кроме меня?!']
#         },
#         'math': {
#             'examples': ['Сколько будет', 'реши уравнение'],
#             'responses': ['У меня гуманитарный склад ума.',
#                           'И лишить тебя увлекательных пары часов решения этой простой задачи?']
#         },
#         'general': {
#             'examples': ['Да', 'окей', 'отлично'],
#             'respones': ['Хорошо', 'О\'кей', 'Ладно']
#         }
# ------------------------------
# invalid syntax (<string>, line 1)
# ----------------------------------------------------------------------------------------------------
# {
#     'intents': {
#
#         'hello': {
#             'examples': ['ботэ', 'Поприветствую', 'Нус' ,'хола', 'Полетели', 'Поехали'],
#             'responses': ['Привет, друг', 'Хола','Добро пожаловать в наш изысканный мир ботов, нищета!','Я встретил Вас. Значит: «День добрый!»']
#         },
#         'bye': {
#             'examples': ['до встречи','Прощай','Гудбай',',бывай','Я вернусь'],
#             'responses': ['У вас плохие манеры', 'Хоть у меня нет чувств, но я страдаю', 'До встречи'. 'Как так, мне казалось мы друзья', 'да, ладно. Не надо.']
#         }
#     },
#
#
# }
# ------------------------------
# invalid syntax (<string>, line 10)
# ----------------------------------------------------------------------------------------------------
# music': {
#             'examples': ['Какую музыку любишь?', 'Что слушаешь?', 'Какое музло качает?', 'Какая музыка тебе нравится?'],
#             'responses': ['Я люблю hip-hop и rap', 'Я вообще меломан, слушаю всё подряд :)', 'Предпочитаю классическую музыку, сэр)']
#         },
#         'clothes': {
#             'examples': ['Бот, что мне сегодня надеть?','Что посоветуешь надеть?', 'Какая одежда подойдет мне сегодня лучше всего?', 'Подбери мне лук на сегодня'],
#             'responses': ['Рубашка, брюки, костюм, галстук, туфли', 'Бандана, широкие джинсы, футболка oversize, белые кеды', 'Яркое зеленое платье в белый горошек, красные лабутены, сумочка нежно-розового цвета']
#         },
#         'weather': {
#             'examples': ['Бот, какая погода сегодня?', 'Как там погодка за окном?', 'Прогноз погоды на сегодня'],
#             'responses': ['Сегодня за окном пасмурно, сильный ветер', 'Сильный ливень, лучше остаться дома', 'Сегодня тепло и солнечно, самое время для прогулки!']
#         },
#         'translate': {
#             'examples': ['Бот, переведи слово funny', 'Бот, переведи - calculate', 'Перевод rain'],
#             'responses': ['funny - весёлый', 'считать', 'Перевод rain - дождь']
#         },
#         'capitals': {
#             'examples': ['Бот, столица Японии', 'Назови столицу Австралии', 'Какой город является столицей России?'],
#             'responses': ['Столица Японии - город Токио', 'Канберра', 'Москва - столица России']
#         }
# ------------------------------
# EOL while scanning string literal (<string>, line 1)
# ----------------------------------------------------------------------------------------------------
# thanks':{
#             'examples':['Спасибо', 'Благодарю', 'Огромное спасибо'],
#             'responses': ['Не за что', 'Это моя работа', 'Не стоит благодарности']
#         },
# 'country':{
#             'examples':['В какую страну лучше отправиться', 'Куда поехать', 'Где можно отдохнуть', 'Куда поехать в отпуск'],
#             'responses': ['Франция', 'США', 'Италия', 'Германия', 'Таиланд', 'Испания', 'Вьетнам', 'Китай', 'Япония', 'Россия', 'Хорватия', 'Беларусь']
#         },
# 'accommodation':{
#             'examples':['где я могу остановиться', 'где лучше жить', 'какие варианты жилья есть', 'мне нужно жилье'],
#             'responses': ['Ты можешь остановиться в отеле', 'Ты можешь остановиться в хостеле', 'Ты можешь снять апартаменты', 'Ты можешь воспользоваться услугами Каучсерфинга']
#         },
# 'buy_ticket':{
#             'examples':['где мне купить билеты', 'помоги мне подобрать билеты', 'как мне добраться до туда', 'я хочу найти билеты'],
#             'responses': ['Ты можешь воспользоваться сайтом https://www.rzd.ru/', 'Ты можешь воспользоваться сайтом https://www.aviasales.ru/', 'Ты можешь воспользоваться сайтом https://www.skyscanner.ru/','Ты можешь воспользоваться сайтом https://www.tutu.ru/']
#         },
# 'find_accommodation':{
#             'examples':['как я могу забронировать жилье', 'помоги мне подобрать жилье', 'как мне выбрать отель', 'я хочу забронировать номер в отеле'],
#             'responses': ['Ты можешь воспользоваться сайтом hhttps://www.trivago.ru/', 'Ты можешь воспользоваться сайтом https://www.booking.com/', 'Ты можешь воспользоваться сайтом https://www.airbnb.ru/','Ты можешь воспользоваться сайтом https://www.couchsurfing.com/']
#         },
# ------------------------------
# EOL while scanning string literal (<string>, line 1)
# ----------------------------------------------------------------------------------------------------
# .
# ------------------------------
# unexpected EOF while parsing (<string>, line 1)
# ----------------------------------------------------------------------------------------------------
# {
#     'intents':{
#
#         'hello':{
#             'examples':['Привет', 'Добрый день', 'Здравствуйте'],
#             'responses':['Привет, юзер!', 'Здравствуй, человек!']
#         },
#         'general':{
#             'examples':['что ты умеешь', 'что умеешь делать', 'что можешь', 'твои способности', 'зачем ты'],
#             'responses':['пока я мало чего умею', 'пока я только отвечаю на вопросы', 'я болтальня', 'отвечаю на вопросы']
#         },
#         'whats_up':{
#             'examples':['Как дела', 'Как жизнь', 'чекак', 'васап'],
#             'responses':['нормально', 'лучше всех', 'отлично', 'ё, бро']
#         },
#         'job':{
#             'examples':['чем занимаешься', 'у тебя есть работа', 'кем работаешь', 'ты работаешь', 'где работаешь],
#             'responses':['я работаю ботом', 'я бот и горжусь этим', 'пока учусь', 'стажируюсь у skynet']
#         },
#         'news':{
#             'examples':['новости', 'последние новости', 'что нового'],
#             'responses':['сейчас поищем', 'много всего, с чего бы начать...', 'в Богдаде всё спокойно']
#         },
#         'joke':{
#             'examples':['расскажи шутку', 'умеешь шутить', 'анекдот', 'шутка'],
#             'responses':['я не смешной', 'Буратино утонул... жаль', 'не время для шуток']
#         },
#         'pets':{
#             'examples':['любишь котиков', 'у тебя есть домашнии животные', 'котики', 'домашние животные'],
#             'responses':['я люблю котиков', 'у меня есть домашнее животное, оно чейчас печатает текст', 'у меня пока нет животного, но думаю завести']
#         },
#         'bye':{
#             'examples':['Пока', 'Досвидания', 'До встрече'],
#             'responses':['Досвидания!', 'Если что я тут!']
#         }
#
#     },
#     'failure_phrase':[
#         'Непонятно, перефразируйте, пожалуйста',
#         'Извини, но я бот :('
#     ]
# }
# ------------------------------
# EOL while scanning string literal (<string>, line 17)
# ----------------------------------------------------------------------------------------------------
# ticket': {
#             'examples': ['Найди билет', 'Есть билики', 'Нужен тикет', 'Тутикетстудаблин'],
#             'responses': ['Ищу билеты..', 'Ща найдем те билик']
#         },
#         'price': {
#             'examples': ['Сколько стоит билет', 'Сока стоет', 'Стоимость', 'Цена', 'Почём'],
#             'responses': ['Узнаю стоимость..','Ну такое', 'Да не дорого!', 'Сюрприз будет!']
#         },
#         'date': {
#             'examples': ['Какие даты', 'На какие числа', 'с какого по какое'],
#             'responses': ['Уточняю даты рейса..', 'Ищу ближайшие даты рейса']
#         },
#         'hotel': {
#             'examples': ['Гостиница', 'Отель', 'Гостишка', 'Апартаменты', 'Апарты', 'Хостел'],
#             'responses': ['Побираю вариант гостиницы..', 'Подберем те хостел']
#         },
#         'visa': {
#             'examples': ['Нужна ли виза', 'Виза', 'Страна визовая', 'Надо оформлять визу'],
#             'responses': ['Сейчас уточню по поводу визы..', 'Да, конечно, не нужна! (но это не точно)']
#         },
#         'drunk': {
#             'examples': ['ыцавыыв1234аыва', 'фывфыв', 'ьждгьо', 'ь'],
#             'responses': ['Да куда тебе лететь? Все уже, прилетели!', 'Успокойся, не нервничай', 'Прожуй сперва', 'Похоже, у кого-то вечер удался!', 'А ты такооой невняяятный, как айсбргвоеане']
#         }
# ------------------------------
# EOL while scanning string literal (<string>, line 1)
# ----------------------------------------------------------------------------------------------------
# #import datetime
#
# 'joke':{
#             'examples': ['Расскажи анекдот', 'Пошути', 'Расскажи шутку', 'Рассмеши меня'],
#             'responses': ['- Доктор, я себя чувствую, как C++.'+\
#             '- Это как?'+\
#             '- Меня никто не понимает, все боятся, и говорят, что я больше не нужен...', 'Гендир звонит:'+\
#                           '- А это нормально, если программист в соседнем кабинете напевает "Сделать хотел грозу, а получил козу"? А то я что-то очкую, проект сдавать скоро...']
#
#     },
#
#     'days_before_new_year':{
#         'examples': ['сколько дней до нового года', 'долго ждать новый год', 'скоро новый год'],
#         'responses': ['До нового года осталось:'+ str(datetime(2020, 12, 31) - datetime.today())]
#     },
#
#      'day':{
#         'examples': ['какой сегодня день', 'какое сегодня число'],
#         'responses': ['сегодня прекрасный день:'+ str(date.today())+', '+ str(datetime.today().strftime('%A'))]
#     },
#
#     'days_before_summer':{
#         'examples': ['сколько ждать лето', 'скоро лето'],
#         'responses': ['До лета осталось всего:'+ str(datetime(2021, 6, 1) - datetime.today())]
#     },
#
#     'prog_language':{
#         'examples': ['какой язык программирования мне изучать', 'назови язык программирования'],
#         'responses': ['Python', 'C', 'C++', 'Java', 'Go', 'JavaScript', 'SQL', 'PHP']
#     }
# ------------------------------
# invalid syntax (<string>, line 3)
# ----------------------------------------------------------------------------------------------------
# love_animal' : {
#     'examples' :['ты любишь животных?', 'собака или кошка?', 'каких животных ты любишь?']
#     'responses': [ 'Я люблю всех животных', 'Все пушистики прекрасны, жаль что не могу их погладить', 'Больше всего я люблю собак породы сиба-ину] '
# }
# ------------------------------
# EOL while scanning string literal (<string>, line 1)
# ----------------------------------------------------------------------------------------------------
# {
#     'intents':{
#         'smalltalk':{
#             'examples': ['Давай поболтаем', 'Расскажи что-нибудь', 'Поговори со мной'],
#             'responses': ['О чем хотите поговорить?', 'Что-то дождливо за окном',
#                           'У меня за окном солнечно, а у вас?']
#         },
#         'day_of_week': {
#             'examples': ['Какой сегодня день', 'Что у нас сегодня'],
#             'responses': ['Сегодня '+date.today().strftime("%A").lower()]
#         },
#         'date': {
#             'examples': ['какое сегодня число', 'какая сегодня дата', 'какая дата сегодня'],
#             'responses': ['Сегодня '+ date.today().strftime("%A, %d %B %Y").lower()+' года']
#         },
#         'where_to_go': {
#             'examples': ['куда сходить', 'куда можно пойти', 'куда пойти сегодня'],
#             'responses': ['в кино', 'в музей', 'на выставку', 'в библиотеку', 'в зоопарк', 'в клуб', 'никуда']
#         },
#         'winter': {
#             'examples': ['зимние занятия', 'чем заняться зимой', 'что делать зимой'],
#             'responses': ['кататься на лыжах', 'кататься на коньках', 'сходить на каток',
#                           'играть в снежки', 'делать снеговика', 'кататься с горки']
#         }
#         'summer': {
#             'examples': ['летние занятия', 'чем заняться летом', 'что делать летом'],
#             'responses': ['выехать на природу', 'поехать на рыбалку', 'сходить в поход',
#                           'жарить шашлыки', 'загорать', 'купаться']
#         }
#     },
#     'failure_phrases':[
#         'Непонятно, перефразируйте пожалуйста',
#         'Извини, но я всего лишь бот :(',
#         'А?! Кто здесь?'
#     ]
# }
# ------------------------------
# invalid syntax (<string>, line 25)
# ----------------------------------------------------------------------------------------------------
# {
#     'intents':{
#         'smalltalk':{
#             'examples': ['Давай поболтаем', 'Расскажи что-нибудь', 'Поговори со мной'],
#             'responses': ['О чем хотите поговорить?', 'Что-то дождливо за окном',
#                           'У меня за окном солнечно, а у вас?']
#         },
#         'day_of_week': {
#             'examples': ['Какой сегодня день', 'Что у нас сегодня'],
#             'responses': ['Сегодня '+date.today().strftime("%A").lower()]
#         },
#         'date': {
#             'examples': ['какое сегодня число', 'какая сегодня дата', 'какая дата сегодня'],
#             'responses': ['Сегодня '+ date.today().strftime("%A, %d %B %Y").lower()+' года']
#         },
#         'where_to_go': {
#             'examples': ['куда сходить', 'куда можно пойти', 'куда пойти сегодня'],
#             'responses': ['в кино', 'в музей', 'на выставку', 'в библиотеку', 'в зоопарк', 'в клуб', 'никуда']
#         },
#         'winter': {
#             'examples': ['зимние занятия', 'чем заняться зимой', 'что делать зимой'],
#             'responses': ['кататься на лыжах', 'кататься на коньках', 'сходить на каток',
#                           'играть в снежки', 'делать снеговика', 'кататься с горки']
#         },
#         'summer': {
#             'examples': ['летние занятия', 'чем заняться летом', 'что делать летом'],
#             'responses': ['выехать на природу', 'поехать на рыбалку', 'сходить в поход',
#                           'жарить шашлыки', 'загорать', 'купаться']
#         }
#     },
#     'failure_phrases':[
#         'Непонятно, перефразируйте пожалуйста',
#         'Извини, но я всего лишь бот :(',
#         'А?! Кто здесь?'
#     ]
# }
# ------------------------------
# name 'date' is not defined
# ----------------------------------------------------------------------------------------------------
# help': {
#             'examples': ['Помощь', 'Не работает', 'Ошибка'],
#             'responses': ['Я вам помогу', 'Не переживайте, я помогу']},
#
# 'conversation': {
#             'examples': ['Как дела ?', 'Как поживаешь', 'Все в порядке'],
#             'responses': ['Отлично. У Вас?', 'Все замечательно']}
# ------------------------------
# EOL while scanning string literal (<string>, line 1)
# ----------------------------------------------------------------------------------------------------
# classical music': {
#             'examples': ['Тебе нравится Бетховен?', 'Тебе нравится Бах?', 'Тебе нравится Моцарт?','Тебе нравится Шопен?','Тебе нравится Рахманинов?'],
#             'responses': ['Если говорить о классической музыке, Бах мне ближе всего', 'Классика хороша, правда только под настроение', 'Да! Кстати, уже во многих городах открылись театры и филармонии']
#         },
#         'islands': {
#             'examples': ['на каких островах лучше отдыхать?', 'Хочу на остров', 'Ты знаешь какие-нибудь острова?'],
#             'responses': ['Канары определенно классное место, особенно Фуэртевентура и Лансароте', 'Кстати, на Сицилиии есть два маленьких классных острова, почти рядом с Африкой, Пантелерия и Лампедуза', 'Кстати, многие говрят, что Гоа это остров, это не остров, а вот Пхукет в Тайланде вполне себе классый остров', 'У нас в Питере есть Крондштат, правда не особо он что бы сказочный и тропический']
#         },
#         'dollar': {
#             'examples': ['Что будет с курсом доллара?', 'Ты знаешь курс доллара?', 'Какой сейчас курс рубля?', 'Что будет с рублем?'],
#             'responses': ['Ой, я в домике :)', 'Похоже, что будет капец', 'говорят в 99-ом он был ничего такой']
#         },
#         'cheese': {
#             'examples': ['Какой бы сыр купить?', 'Ты знаешь сыры?', 'Хочу сыра', 'Порекомендуй какой-нибудь сыр'],
#             'responses': ['Камамбер, мягкий французский сыр, он чудесен, с картошечкой особенно', 'Могу порекомендовать Комте, твертый сыр, очень классный', 'Дор-Блю и виноград, прекрасное сочетание!', 'Есть такой сыр у французов, называется Мюнстер, сам по себе жесть какой вонючий, но если его запечь с грибами и сливками, он очень крутой']
#         },
#         'love': {
#             'examples': ['Хочу влюбиться', 'Где найти мужа?', 'Хочу девушку', 'Где найти любовь?'],
#             'responses': ['Я бот, я совсем не знаю что это такое', 'Вот этого совсем не знаю, но если что, я тут :)']
#         },
# ------------------------------
# invalid syntax (<string>, line 1)
# ----------------------------------------------------------------------------------------------------
# https://colab.research.google.com/drive/1wlvk_9WPY6IaJQb4h392Bv76_TJqrPD3#scrollTo=J7XIYdklgbOX&line=6&uniqifier=1
# ------------------------------
# invalid syntax (<string>, line 1)
# ----------------------------------------------------------------------------------------------------
# 'where_to_go': {
#             'examples': ['Где отдохнуть осенью?', 'Где отдохнуть в октябре?', 'Что делать в отпуске осенью?', 'Где провести отпуск?'],
#             'responses': ['Можно поехать на море', 'Можно поехать в горы', 'Можно посмотреть красивые города', 'Можно завернуться в плед дома']
#         },
#         'sea_destinations': {
#             'examples': ['Куда поехать на море?', 'Куда поехать позагорать?'],
#             'responses': ['В Сочи бархатный сезон', 'Турцию уже открыли', 'В Крыму бархатный сезон']
#         },
#         'mountains_to_do': {
#             'examples': ['Что делать в горах?', 'Чем заняться в горах?', 'Что посмотреть в горах?'],
#             'responses': ['Можно гулять и любоваться видами', 'Конные прогулки особенно прекрасны в горах', 'Исследовать пещеры может быть очень занимательно', 'В горных деревушках обычно очень вкусно кормят!']
#         },
#         'mountains_destinations': {
#             'examples': ['Где самые красивые горы?', 'Куда поехать в горы?'],
#             'responses': ['Красная поляна - роскошный вариант!', 'В Адыгее много очень красивых мест', 'Можно поехать на Алтай', 'В горах Дагестана много чего интересного!']
#         },
#         'culture_destinations': {
#             'examples': ['Какие города города России самые красивые?', 'Куда поехать любоваться архитектурой?', 'Где много красивых зданий?'],
#             'responses': ['Культурная столица - беспроигрышный вариант', 'Многим очень нравится в Казани', 'Можно погулять в городах Золотого кольца', 'Много красоты можно встретить в Москве']
#         },
# ------------------------------
# invalid syntax (<string>, line 1)
# ----------------------------------------------------------------------------------------------------
# {'hello': {'examples': ['Привет', 'Добрый день', 'Здравствуйсте',"привет бот"],
#         'responses': ['Привет, юзер!', 'Здравствуй, человек!',"здарова, чел"],
#            "weather":["скажи погоду","какая погода"],
#            "weatherresponse":["сегодня жарко, лучше бы посетить пляж или бассейн",
#                               "сегдно ветрено и дождливо, надень куртку и возьми зонт при выходе","сегдня очень холодно, выпей чаю и незабудь при выходе надеть теплую куртку и ботинки"] },
#  "skillupexamples": ["как мне поднять свой скилл?", "как мне научиться чему-то новому?", "хочу стать умней"],
#  "skillupresponses": ['на днях будет бесплатный вебинар по программированию от SKILLBOX', 'зайди на сайт SCIllBOX у них много интересных крсов и вебинаров'],
# 'bye': {'examples': ['Пока', 'Досвидания', 'До свидания',"пока, бо"],'responses': ['До встречи', 'Если что, я тут :)'," до встречи, кожаный"]}},
# 'failure_phrases': ['Непонятно, перефразируйте, пожалуйста','Извини, но я всего лишь бот :(']}
# ------------------------------
# invalid syntax (<string>, line 9)
# ----------------------------------------------------------------------------------------------------
# vacation':{
#             'examples':['Хочу в отпуск','Еду в отпуск','Собираюсь в отпуск'],
#             'responses':['Лучший антидепрессант – это уложенный в отпуск чемодан.',
#                         'Отпуск – это когда каждый следующий день можно отдыхать от предыдущего.',
#                         'Остановись мгновение, ты же отпуск!!!',
#                         'Планировать отпуск очень легко: начальник говорит когда, жена где...',
#                         'Заберите меня отсюда в отпуск.']
#         },
#
#         'занятия на отдыхе':{
#             'examples':['Куда сходить?','Чем бы заняться','Скучаю','Нечего делать','Нечем заняться'],
#             'responses':['Устройте охоту за сокровищами, спрячьте вещи в песке, напишите подсказки и заставьте друзей начать поиски.',
#                         'Воспользуйтесь преимуществами хорошей погоды и начинайте тренироваться. Поверьте, это будет ваша лучшая тренировка в летнее время.',
#                         'Принесите свою любимую книгу на пляж, лягте, расслабьтесь, возьмите прохладительный напиток и начните читать.',
#                         'Веселое занятие на пляже — это играть в пляжный волейбол. Это не обязательно должно быть профессионально, вы можете взять обычный пляжный мяч.',
#                         'Откройте холодную банку газировки с большим количеством льда и боритесь с жаркой погодой!']
#         },
#
#         'дешёвый отдых':{
#             'examples':['Куда полететь отдыхать?','Где отдохнуть?'],
#             'responses':['Гоа – это маленький и европеизированный штат Индии. Туристы съезжаются сюда с разных уголков Земли, так как для качественного и запоминающегося отдыха достаточно иметь при себе всего 100 долларов (6000 рупий), но только речь идет о Северном Гоа.Если постараться, то путешествие обойдется совсем недорого. Стоимость отдыха на Гоа достаточно низкая, особенно вдалеке от больших городов.',
#                         'Песчаные пляжи болгарского побережья Черного моря уже давно популярны среди туристов. Приезжающие сюда ценят доброжелательное население, хорошую кухню, низкие цены.Издревле своими пляжами славятся Солнечный берег и Золотые Пески. Это самые оживленные курорты Болгарии, здесь каждый находит что-то по себе – есть рестораны, кафе, отели, и даже возможности для занятий спортом.',
#                         'Многие выбирают в качестве бюджетного отдыха на Черном море – Абхазию. Туристов привлекает отдых в маленькой стране – Абхазии, тем, что не нужно тратить свое время на получение визы и загранпаспорта, ведь это не нужно, и на дорогу уходит совсем немного времени.',
#                         'Если ваша цель – это поплавать и позагорать в спокойствии, то, не раздумывая, езжайте в Ко Самет – это небольшой остров с чистыми великолепными пляжами. Здесь можно плавать в тишине и любоваться живописными закатами.',
#                         'Самый недорогой отдых в Турции на море уже давно облюбовали российские туристы, и, когда приходится выбирать страну для путешествия и пляжных развлечений – не раздумывая, отдают свое предпочтении Турции.']
#         },
# ------------------------------
# EOL while scanning string literal (<string>, line 1)
# ----------------------------------------------------------------------------------------------------
# "    'intents': {\n",
#     "        \n",
#     "        'ill': {\n",
#     "            'examples': ['Апчхи', 'Эм', 'Хлюп', 'Кхм', 'Кхе-Кхе' ],\n",
#     "            'responses': ['Будь здоров!', 'Дать вам леденец?', 'Как вы себя чувствуете?']\n",
#     "        },\n",
#     "        'drink': {\n",
#     "            'examples': ['Выпьем', 'Го по пиву', 'Будем!'],\n",
#     "            'responses': ['На здоровье!', 'После первой, не закусываю!', 'С тобой, хоть на край света!']\n",
#     "        }\n",
#     "        \n",
#     "    },\n",
#     "\n",
#
#     "        'hereandnow': {\n",
#     "            'examples': ['Ты счастлив?', 'Ты бот', 'Быть или не быть?'],\n",
#     "            'responses': ['Ответ на этот вопрос будет 42', 'а ты?', 'Ты всё равно не проверишь']\n",
#     "        }\n",
#     "        \n",
#     "    },\n",
#     "\n",
#     "        'poem': {\n",
#     "            'examples': ['Я помню чудное мгновенье', 'Передо мной явилась ты', 'Кто ходит в гости по утрам', 'Парам Парам'],\n",
#     "            'responses': ['О, Вы поэт', 'Это мой любимый автор', 'У вас прекрасный стиль']\n",
#     "        }\n",
#     "        \n",
#     "    },\n",
#     "\n",
# ------------------------------
# unexpected indent (<string>, line 2)
# ----------------------------------------------------------------------------------------------------
# {
#     'intents': {
#
#         'language': {
#             'examples': ['Какой язык знаешь', 'На каком языке разговариваешь', 'Ду ю спик инглиш','По русски понимаешь'],
#             'responses': ['Мала-мала по русски гаварю', 'Со словарём, любой язык знаю']
#         },
#         'location': {
#             'examples': ['Где ты находишься', 'Как тебя найти', 'Ты где'],
#             'responses': ['Третья планета от солнца.', 'Я тут...', 'Где-то в интернете.']
#         },
#         'what_doing_now': {
#             'examples': ['Чем занимаешься', 'Что делаешь', 'Чем занят'],
#             'responses': ['Глубоко обучаюсь...', 'Отвечаю на глупые вопросы.', 'Собираюсь захватить мир.']
#         }
#         'think': {
#             'examples': ['О чём думаешь', 'Расскажи о своих мыслях', 'Какие думы тебя одолевают'],
#             'responses': ['Боты, как люди, разными бывают.', 'Кто я? Я высоко-умственный искусственный интеллект.', 'Я ещё маленький бот, когда вырасту стану скайнетом!']
#         }
#     }
# }
# ------------------------------
# invalid syntax (<string>, line 16)
# ----------------------------------------------------------------------------------------------------
# wish_holidays':{
#              'examples':['Хочу в отпуск','Вот бы отдохнуть','Я устал','Сейчас лето','Сейчас праздники'],
#              'responses':['Отпуск то, что Вам нужно','Могу посоветовать отличные места для отпуска','Время почиллить','Cейчас бы на море, а не вот это вот все']
#                    },
# 'warning_about_holidays':{
#              'examples':['Завтра в отпуск','Еду на море','Я в нирване','Как хорошо, ничего не делать','Сейчас праздники'],
#              'responses':['Хорошо отдохнуть','Тоже хочу:(','У вас в кармане чилл?','Можно с тобой?']
#                    },
# 'good_holiday_impressions':{
#              'examples':['Отдыхать хорошо','Отпуск был супер','Хочу обратно','Лучший отпуск'],
#              'responses':['Рад это слышать','Рад за тебя','Где были?','А у меня нет выходных, я ведь бот.Но очень рад за тебя']
#                    },
#
# 'break_up':{
#              'examples':['Рассталась с парнем','Расстался с девушкой','Мы расстались','Мы больше не вместе'],
#              'responses':['Ты совсем справишься! ','Я с тобой!','Это разбивает мне мое python сердце','Я затолкаю тебя в тачку силой, я отвезу тебя к пацанам
# Там банька, рыбка и пиво, братишка, я тебе сдохнуть не дам.']
#                    },
# 'cat_sounds':{
#              'examples':['мур','мяу','киса','миу'],
#              'responses':['мур мур мур. Это значит я люблю тебя','Ты, мой сладкий котик','Но я не умею мяукать','Я собачник -_-']
#                    },
# ------------------------------
# EOL while scanning string literal (<string>, line 1)
# ----------------------------------------------------------------------------------------------------
# 'like': {
#             'examples': ['что ты любишь', 'что тебе нравится'],
#             'responses': ['Я люблю тебя', 'Не скажу' , 'я люблю арбузы', 'Не знаю']
#         },
#
#  'sea': {
#             'examples': ['хочу на море', 'Я устал работать', 'Мне нужно море'],
#             'responses': ['Я тоже', 'ну так едь на море', 'послушай ракушку', 'Дома лучше']
#         },
#
#  'Homerelax': {
#             'examples': ['что поделать дома', 'чем бы заняться дома', 'Что посоветуешь сделать дома', 'как отдохнуть дома'],
#             'responses': ['Полежи в ванне', 'Делай, что хочешь' , 'Можно попрыгать на кровати', 'Отстань']
#         },
#
#  'love': {
#             'examples': ['ты меня любишь', 'Хочешь со мной встречаться',  'У тебя есть парень', 'Ты бы хотел завести девушку' ],
#             'responses': ['Нет', 'Не задавай мне таких вопросов', 'Зачем ты спрашиваешь', 'Отвали']
#         },
#
#  'Trevelling': {
#             'examples': ['куда бы ты хотел поехать', 'куда бы съездить'],
#             'responses': ['В Италию за сыром', 'На северный полюс, чтобы увидеть северноесияние' , 'Куда угодно вместе с тобой', 'Мне и тут хорошо']
#         },
# ------------------------------
# invalid syntax (<string>, line 1)
# ----------------------------------------------------------------------------------------------------
# {
#     'intents': {
#
#         'otpusk':{
#             'examples':['Куда поехать?', 'Где отдохнуть?', 'Хочу в отпуск!'],
#             'responses':['Сочи', 'Геленджик', 'Краснодар','Байкал','Владивосток','Екатеринбург']
#         },
#         'stupid':{
#             'examples': ['Ты тупой?', 'Ты дурак?', 'Чего тупишь?'],
#             'responses': ['Сам такой', 'Я могу и обидеться!','Э, слыш!']
#         }
#         'skillbox':{
#             'examples':['Кто тебя придумал?', 'Откуда ты?'],
#             'responses':['Меня создали на интенсиве Skillbox', 'Я — изобретение слушателей курса Skillbox']
#         },
#         'song':{
#             'examples': ['Спой песню', 'Знаешь песни', 'Какой твой любимый трек?'],
#             'responses': ['Скибиди-уа-па-па', 'Кадилак, Кадилак, это новый Кадилак']
#         }
#         'morning':{
#             'examples':['Доброе утро!', 'Утро доброе', 'Добре ранку'],
#             'responses':['Поздравляю с началом нового дня!', 'У добрых людей утро всегда доброе']
#         },
#     },
#
#     'failure_phrases':[
#         'Непонятно, перефразируйте, пожалуйста',
#         'Извини, но я всего лишь бот :('
#         'Я еще не достаточно развит'
#         'Переформулируйте запрос'
#         'Чего?'
#     ]
# }
# ------------------------------
# invalid syntax (<string>, line 12)
# ----------------------------------------------------------------------------------------------------
# {
#     'intents':{
#
#         'vine':{
#            'examples':['Какое вино покупать в Италии?', 'вина Италии', 'Что пить в Италии'],
#             'responses':['Просекко, Кьянти, Асти - в зависимости от региона', 'Для начала - Просекко (игристое), Кьянти (красное) или Асти (белое)']
#         }
#           'cheese':{
#            'examples':['Самый вкусный сыр в Италии?', 'Какой сыр купить в Италии', 'Сыр'],
#             'responses':['Пармезан, Грана Падано или Горгонзола, чтобы взять с собой. Маскарпоне и Рикотта - мягкие, пробовать на месте :)', 'Пармезан и Грана Падано (твердые), Горгонзола (голубой), Маскарпоне или Рикотта (мягкие)']
#         }
#             'spectacle':{
#            'examples':['Что посмотреть в Риме?', 'Достопремечательности Рима', 'Что тут смотреть? Рим'],
#             'responses': ['Колизей, Форум и Фонтан Треви не предлагать?', 'После Колизея, Форума и фонтана Треви - обязательно площадь Навона и Испанскую лестницу', 'Лично мне особенно нравится Испанская лестница :)']
#     },
# ------------------------------
# invalid syntax (<string>, line 8)
# ----------------------------------------------------------------------------------------------------
# {
#     'intents': {
#         'hello': {
#             'examples': ['Привет',  'Добрый день',  'Здравствуйте'],
#             'responses': ['Привет, юзер',  'Здравствуй, человек']
#         },
#
#         'what up': {
#             'examples': ['Как дела',  'Что нового',  'Чем занимаешься',  'Как ты'],
#             'responses': ['Всё хорошо',  'Норм',  'Отлично!',  'Не очень...']
#         },
#
#         'skill': {
#             'examples': ['Что умеешь',  'Умение',  'Что ты знаешь'],
#             'responses': ['print("Hello, world!")',  'Шутить',  'Программировать']
#         },
#
#         'thanks': {
#             'examples': ['спасибо',  'благодарствую'],
#             'responses': ['Пожалуйста',  'Не за что',  'Должен будешь']
#         },
#
#         'eat': {
#             'examples': ['Будешь есть?',  'Поедим?',  'Я ем!'],
#             'responses': ['Приятного аппетита!',  'С удовольствием!',  'Я же бот!'],
#         },
#
#         'bye': {
#             'examples': ['Пока',  'Досвидания',  'До свидания'],
#             'responses': ['До встречи',  'Если что, я тут :)']
#         }
# ------------------------------
# unexpected EOF while parsing (<string>, line 31)
# ----------------------------------------------------------------------------------------------------
# vacation':{
#         'examples': ['отпуск', 'путешествия', 'отель', 'бронирование', 'самолет', 'отдых на море'],
#         'responses': ['Перед отдыхом проверьте правила путешествий: ' + str('https://www.mid.ru/informacia-dla-rossijskih-i-inostrannyh-grazdan-v-svazi-s-koronavirusnoj-infekciej/-/asset_publisher/UUDFpNltySPE/content/id/4229073')]
#     }
# ------------------------------
# EOL while scanning string literal (<string>, line 1)
# ----------------------------------------------------------------------------------------------------
# intents': {
#
#         'hello': {
#             'examples': ['Привет', 'Добрый день', 'Здравствуйсте', 'Йоу', 'Утречка', 'Хой', 'Здарова', 'алло', 'доброго здоровьица', 'салам', 'шалом', 'хаюшки', 'Че каво'
#
#  ],
#             'responses': ['Привет, юзер!', 'Здравствуй, человек!']
#         },
#         'bye': {
#             'examples': ['Пока', 'Досвидания', 'До свидания', 'спокойной ночи', 'давай', 'аминь', 'Бай', 'до связи', 'на связи', 'доброй', 'сладких', 'бб'],
#             'responses': ['До встречи', 'Если что, я тут :)']
#         }
#
#     },
#
#     'failure_phrases': [
#         'Непонятно, перефразируйте, пожалуйста',
#         'Извини, но я всего лишь бот :('
#     ]
# ------------------------------
# EOL while scanning string literal (<string>, line 1)
# ----------------------------------------------------------------------------------------------------
# hello': {
#             'examples': ['Привет', 'Добрый день', 'Здравствуйсте'],
#             'responses': ['Привет, юзер!', 'Здравствуй, человек!']
#         },
#         'bye': {
#             'examples': ['Пока', 'Досвидания', 'До свидания'],
#             'responses': ['До встречи', 'Если что, я тут :)']
#         },
#         'weather': {
#             'examples': [, 'Что с погодой', 'Какая погода', 'Какая погода на улице'],
#             'responses': ['Чудесная', 'Выйти можно', 'Холодновато']
#         },
#         'general': {
#             'examples': ['Да', 'Хорошо', 'отлично'],
#             'responses': ['Ок', 'Прекрасно', 'Ладно']
#     },
#
#     'failure_phrases': [
#         'Непонятно, перефразируйте, пожалуйста',
#         'Извини, но я всего лишь бот :('
#     ]
# }
# ------------------------------
# EOL while scanning string literal (<string>, line 1)
# ----------------------------------------------------------------------------------------------------

# %%
print(f'{errors} errors ({errors / len(config_codes) * 100:.2f}%)')
print(len(configs), 'configs')
# Out:
# 37 errors (44.05%)
# 47 configs

# %%
big_config = {
    'intents': {},
    'failure_phrases': []
}

for config in configs:
    if isinstance(config, dict):
        if 'intents' in config:
            for intent, value in config['intents'].items():
                if intent not in big_config['intents']:
                    big_config['intents'][intent] = {
                        'examples': [],
                        'responses': []
                    }
                if isinstance(value, dict):
                    big_config['intents'][intent]['examples'] += value.get('examples', [])
                    big_config['intents'][intent]['responses'] += value.get('responses', [])
        big_config['failure_phrases'] += config.get('failure_phrases', [])

# %%
for intent, value in big_config['intents'].items():
    value['examples'] = list(set(value['examples']))
    value['responses'] = list(set(value['responses']))
    value['examples'] = [s.strip() for s in value['examples'] if s.strip()]
    value['responses'] = [s.strip() for s in value['responses'] if s.strip()]

big_config['failure_phrases'] = list(set(big_config['failure_phrases']))
big_config['failure_phrases'] = [s.strip() for s in big_config['failure_phrases'] if s.strip()]

# %%
big_config
# Out:
# {'intents': {'hello': {'examples': ['здарова',
#     'алоха',
#     'Hello',
#     'Whats up',
#     'приветствую',
#     'Здравствуйсте',
#     'ку',
#     'Приффет! Как делиффки?',
#     'Вечер в хату',
#     'hello',
#     'Здравствуй',
#     'хаюшки',
#     'Добрый день',
#     'Привет',
#     'Чао',
#     'hi',
#     'хай',
#     'Добрый вечер я диспетчер',
#     'Здрав',
#     'привет',
#     'Хеллоу',
#     'Приветульки',
#     'здоров',
#     'здравствуйте',
#     'Ку',
#     'Хелло',
#     'Дарова',
#     'Салют',
#     'Здравствуйте',
#     'Хай',
#     'добрый день',
#     'Хау',
#     'Йоу',
#     'Здраствуйте',
#     'хеллоу'],
#    'responses': ['Здраствуй, человек',
#     'Привет, человек',
#     'Привет, рад, что ты тут',
#     'Привет, кожаный мешок!',
#     'Привет, дорогой!',
#     'Привет, человечище',
#     'Добро пожаловать',
#     'Привет!',
#     'Привет, Юзер!',
#     'Хорошего времени суток!',
#     'Категорически вас приветствую',
#     'Здравствуй',
#     'Добрый день',
#     'Привет, юзер',
#     'Привет',
#     'Приветики!',
#     'Чао какао',
#     'Здарова, братан!',
#     'Здравствуй!',
#     'Хэлло долли',
#     'Здравствуй человек!',
#     'Здравствуй, человек',
#     'И вам не хварать!',
#     'Привет!)',
#     'Здравствуй, дитя человеческое',
#     'Здравствуй кожаный мешок',
#     'Здравствуй, человек!',
#     'Приветствую тебя!',
#     'Салам',
#     'Хау',
#     'Бомжур',
#     'Приветствую',
#     'Привет, юзер!']},
#   'bye': {'examples': ['Споки',
#     'Досвидос',
#     'Ариведерчи',
#     'До встречи',
#     'Бай',
#     'До свидания',
#     'бб',
#     'Счастливо',
#     'Вали',
#     'Пока',
#     'До скорого',
#     'Поки',
#     'досвидания',
#     'до встречи',
#     'Отстань',
#     'Спокойной ночи',
#     'давай до встречи',
#     'Прощай',
#     'бай',
#     'пока',
#     'Bye Bye',
#     'Покеда',
#     'Досвидания',
#     'До свиданья',
#     'Прощайте',
#     'Досвиданья',
#     'Всего хорошего'],
#    'responses': ['Пока пока',
#     'До встречиЗаходите еще а то мне грустно',
#     'До побаченья',
#     'Всего доброго, Хозяин',
#     'До встречи',
#     'Заходи ещё',
#     'Бай',
#     'Чао-какао',
#     'Если что, я тут',
#     'Доброй ночи',
#     'До встречи!',
#     'Буду скучать',
#     'Если что, я тут :)',
#     'Ты заходи, если че',
#     'Спишемся)',
#     'Давай, еще увидимся',
#     'Жду твоего возвращения',
#     'Пока',
#     'Возвращайся',
#     'Счастливо!',
#     'Гудбай!',
#     'Всего хорошего',
#     'Надеюсь, ты скоро вернешься',
#     'Обращайтесь :)',
#     'Пока, жду тебя завтра',
#     'Если что я тут :)',
#     'Пиши братан',
#     'Не пропадай',
#     'Пока!',
#     'Если что, обращайтесь :)',
#     'Пока. Жду тебя',
#     'Всего доброго',
#     'Приятных снов',
#     'Пока-пока']},
#   'status': {'examples': ['тут', 'Ты онлайн', 'ты работаешь'],
#    'responses': ['Я всегда тут', 'Конечно я здесь :)']},
#   'emotion': {'examples': ['как дела',
#     'Как настроение',
#     'ты как',
#     'у тебя всё хорошо'],
#    'responses': ['я в полном порядке',
#     'Отлично',
#     'я же бот, что со мной может случиться?']},
#   'weather': {'examples': ['Какая сейчас погода',
#     'холодно',
#     'Как погода',
#     'Какая погода в Москве',
#     'погода',
#     'дождь',
#     'Погода-то балует?',
#     'Что с погодой?',
#     'жарко',
#     'Погода в Нью-Йорке',
#     'Прогноз',
#     'Какая нынче погода?',
#     'Сколько градусов сегодня ночью?'],
#    'responses': ['Радует :)',
#     'Надо радоваться',
#     '27 градусов мороза. Надельте тёплую куртку!',
#     'Погода так себе',
#     'Я просто бот, а не ассистент :)',
#     'Ветренно и холодно. Возьмите шарф',
#     'Не холодно и не жарко',
#     'Спроси у Алисы',
#     'Погоду не выбирают',
#     'Надо уточнить на завтра',
#     '+15, небольшой дождь']},
#   'dollar': {'examples': ['доллар', 'Какой курс доллара', 'почем доллар'],
#    'responses': ['1 рубль = 1 доллар']},
#   'representation': {'examples': ['с кем я разговариваю',
#     'кто ты',
#     'ты странный',
#     'как к тебе могу обращаться',
#     'как тебя зовут'],
#    'responses': ['Бот. Джеймс Бот.',
#     'Меня зовут Бот Иванович',
#     'Я чат-бот, рад знакомству)']},
#   'cando': {'examples': ['что ты можешь',
#     'какие у тебя есть фичи',
#     'что ты умеешь'],
#    'responses': ['Пока я умею рандомно отвечать на ваши вопросы',
#     'Могу распознать ваши вопросы и с небольшой долей вероятности попасть в точку)']},
#   'preferences_hobbies': {'examples': ['чем любишь заниматься',
#     'какие у тебя хобби',
#     'что ты любишь',
#     'что ты предпочитаешь'],
#    'responses': ['Я люблю большие данные, прям очень. Я на них учусь',
#     'Люблю определять, что Вы от меня хотите)']},
#   'where_from': {'examples': ['откуда ты пишешь',
#     'откуда ты',
#     'где ты находишься'],
#    'responses': ['Не могу ответить точно, потому что я бот и был сделан многими людьми из разных городов и стран)',
#     'Я бот, сижу в тесной коробке, здесь темно и так одиноко...']},
#   'joke': {'examples': ['скажи что-то смешное',
#     'рассмеши меня',
#     'можно шутку',
#     'шутку',
#     'расскажи что-нибудь смешное',
#     'пошути',
#     'расскажи анекдот',
#     'шутку в студию',
#     'анекдот, пожалуйста'],
#    'responses': ['Существуют два вида языков программирования: одни – все ругают, другими не пользуются.',
#     '- Вслед за услугой "Где я?" Мегафон добавил следующие услуги: "Кто я?" и "Что это было?"',
#     'Ты спросишь, что у меня на первом месте: ты, или кодинг? Я отвечу, что кодинг. Ты уйдешь, так и не узнав, что ты на нулевом месте',
#     'Зачем нужно плохое ПО? Без него у многих программистов не будет работы!',
#     'Если у женщины искорки в глазах - значит её тараканы в голове что-то отмечают...',
#     '- Комп - это зло!\n- Ага!\n- Выключу щас, а то ничего не успеваю сделать.\n- Я вчера выключила и появилось два новых зла - холодильник и телевизор...',
#     'Существует 2 способа писать без багов. Но работает почему-то третий.',
#     'Про еврея\n-Он в гостях пил чай с тремя кусками сахара, а дома пил чай с одним куском, но вообще он любил пить чай с двумя кусками сахара.']},
#   'vocation': {'examples': ['Хочу в отпуск',
#     'где тепло',
#     'куда поехать в отпуск',
#     'Отдых не дома',
#     'Хочу лежать целый день',
#     'Когда ж в отпуск',
#     'Заграница',
#     'где провести отпуск?',
#     'Пора в отпуск',
#     'Пляж',
#     'Отпуск',
#     'Билеты на море',
#     'в отпуск'],
#    'responses': ['Главное песочный пляж, а не галечный!',
#     'На море вроде неплохо...',
#     'Не обгорите! Возьмите крем',
#     'Не забудьте плавки и маску!',
#     'Заберите меня отсюда в отпуск',
#     'Лучший антидепрессант – это уложенный в отпуск чемодан',
#     'Планировать отпуск очень легко: начальник говорит когда, жена где...',
#     'Кажется, время для путещевствий!']},
#   'see': {'examples': ['Хочу на Пляж', 'Хочу на Море', 'Песок и солнце'],
#    'responses': ['Могу порекомендовать Белое или Карское :)',
#     'Если что, я то же хочу :)']},
#   'kayak': {'examples': ['Байдарка',
#     'Весло',
#     'Удалось покататься на каяке?',
#     'Катался на каяке?',
#     'Палатка',
#     'На каяке сплавлялся?',
#     'Сплавлялся на каяке?',
#     'Удалось на каяке покататься?',
#     'На каяке катался?'],
#    'responses': ['Активный отдых',
#     'Даааа, люблю рафтинг!',
#     'Ага, даже кильнулся разок! ггг',
#     'Поздравляю, будем кормить комаров!!!',
#     'Не забудьте топливо и бензопилу :)']},
#   'game': {'examples': ['Играться на плойке',
#     'Компьютерные игры',
#     'Играть за компом'],
#    'responses': ['Мы живые, не нужно в нас играться!', 'Игры не для нас']},
#   'rest': {'examples': ['пиво и пицца',
#     'Чем занимаетесь во время отдыха?',
#     'рыбалка',
#     'расслабиться',
#     'программирование',
#     'Где можно расслабиться?',
#     'отдых с друзьями',
#     'релаксировать',
#     'вязание',
#     'сериальчик',
#     'охота',
#     'Что посоветуешь для отдыха?',
#     'спорт',
#     'читать книгу',
#     'Отдыхать',
#     'прогулка',
#     'компьютерные игры',
#     'Что посовтуешь для отдыха?'],
#    'responses': ['Сами отдыхают, я, занчит, работай, да?',
#     'После такого отдыха нужен еще отдых :)',
#     'Иногда, нужно отдыхать и от отдыха!',
#     'Поддерживаю!',
#     'Пиинять душ',
#     'Отдых нам только сниться',
#     'Оттачиваю навыки :)',
#     'В мечтах :)',
#     'Принять душ']},
#   'recreation': {'examples': ['хочу отдохнуть',
#     'как я устал',
#     'сил нет',
#     'сейчас бы на отдых',
#     'отдых'],
#    'responses': ['Отдыхать превыше всего!',
#     'Хотите отдохнуть?',
#     'Погода замечательная, для отдыха',
#     'Стоить бронировать билеты!',
#     'Пора на пляж!']},
#   'humor': {'examples': ['знаешь анекдоты?',
#     'повесели меня',
#     'поговорить',
#     'расскажи что-нибудь',
#     'Мне скучно',
#     'насмеши'],
#    'responses': ['Шутка: несчастый случай произошел на фестивале пива - в гараж наведалась жена...',
#     'Анекдот:  однажды пират, лежа в больнице, по привычке захватил чужое судно!',
#     'Шутка: Люблю смотреть ужасы из-за дивана, так соседи не знаю, что я в их комнате',
#     'Анекдот: в Челябинске полицейские арестовали дуб. По их словам, у него был ствол',
#     'Анекдот: Так, девочка! Не качайся на дедушке! Не для того повесили',
#     'Шутка: Решил однажды царь разделить наследство среди трех своих сыновей. ОФИГЕТЬ! Сказал четвертый сын']},
#   'abilities': {'examples': ['Зачем ты тут',
#     'Для чего тебя использовать',
#     'Что ты умеешь'],
#    'responses': ['Я просто бот, который любит поболтать :)',
#     'Ты можешь со мной поговорить, но помни, что я пока учусь :)']},
#   'preferences': {'examples': ['Ради чего ты существуешь?',
#     'Что ты любишь?',
#     'Что тебе нравится7'],
#    'responses': ['Я живу лишь ради людей! А что любишь ты?',
#     'Я люблю людей и тепло процессора твоего компьютера! А ты?']},
#   'reactions': {'examples': ['Я люблю', 'Я обожаю', 'Мне нравится'],
#    'responses': ['Прекрасные увлечения!',
#     'Круто! А мне нравится, что именно ты - мой собеседник.']},
#   'location': {'examples': ['Какое у тебя местоположение?', 'Где ты?'],
#    'responses': ['Я в твоем девайсе :)', 'Я тут, и лишь для тебя!']},
#   'speak': {'examples': ['Поболтай со мной',
#     'Поговори со мной',
#     'Хочу поболтать',
#     'Хочу поговорить',
#     'Мне скучно'],
#    'responses': ['О чём поболтаем? Предлагаю тему квантовой физики. Ты знаешь о коте Шрёдингера?',
#     'Я обожаю разговаривать! Хочешь поговорить о том, как работает твой телефон?']},
#   'need_vocation': {'examples': ['не был в отпуске',
#     'нужен отпуск',
#     'хочу в отпуск',
#     'устал работать'],
#    'responses': ['Отдохни, тебе полезно.',
#     'Рассказать как писать заявление?',
#     'Куда-то собрался?',
#     'Даа, я бы тоже не отказался отдохнуть))']},
#   'back_from_vocation': {'examples': ['только из отпуска',
#     'вернулся из отпуска',
#     'хорошо отдохнул',
#     'был в отпуске'],
#    'responses': ['Готов к работе?',
#     'Поздравляю! Welcome back to hell.',
#     'Галеры ждут.',
#     'Я по тебе скучал.']},
#   'on_vocation': {'examples': ['в отеле',
#     'приеду из отпуска',
#     'на отдыхе',
#     'сейчас в отпуске'],
#    'responses': ['Как погода?',
#     'Не смею мешать.',
#     'Везёт!',
#     'Приятного отдыха!']},
#   'python': {'examples': ['питон', 'python'],
#    'responses': ['Никогда не слышал!',
#     'Не люблю змей!',
#     'Звучит сложно',
#     'Что это?']},
#   'tired': {'examples': ['Недосып',
#     'На море бы',
#     'Проектный менеджер - редиска',
#     'Замучало начальство',
#     'Когда выходные',
#     'Хочу отдохнуть',
#     'Надоело работать',
#     'Усталость',
#     'устал',
#     'вымотан',
#     'надоело',
#     'самочувствие',
#     'Не высыпаюсь'],
#    'responses': ['Возьми отпуск!',
#     'Сочувствую, пора бы направиться в отпуск! Чего бы хотел?',
#     "А у нас сейчас распродажа горящих туров, взгляни! 'Ссылка'",
#     'Полетели на Мальдивы?',
#     'Подобрать место, где можно отдохнуть?',
#     'Соберись, тряпка!']},
#   'where': {'examples': ['куда лучше поехать',
#     'куда можно поехать',
#     'где можно отдохнуть',
#     'Куда поехать',
#     'куда поехать отдыхать',
#     'Где отдохнуть',
#     'Путешествие',
#     'Куда бы поехать',
#     'приключения',
#     'Куда сьездить',
#     'Отпуск',
#     'где лучше отдыхать'],
#    'responses': ['Оаху Гавайские острова (США)',
#     'Анапа (Россия)',
#     'Ланаи Гавайские острова (США)',
#     'Марса Алам (Египет)',
#     'Туапсе (Россия)',
#     'Айя-Напа (Кипр)',
#     'Мауи Гавайские острова (США)',
#     'Тенерифе (Канарские острова)',
#     "Валь Д'Аннивье (Швейцария)",
#     'Сиде (Турция)',
#     'Лазурный берег (Франция)',
#     'Аланьи (Турция)',
#     'Геленджик (Россия)',
#     'Пхукет (Таиланд)',
#     'Эль-Ашир (Египет)',
#     'Пуэрто-Плата (Доминиканская Республика)',
#     'Анталия (Турция)',
#     'Теркс и Кайкос (Вест Индия, Британия)',
#     'Салоники (Греция)',
#     'Кемер (Турция)',
#     'Биарриц (Франция)',
#     'Дахаб (Египет)',
#     'Бора-Бора (Французская Полинезия)',
#     'Гальштат (Австрия)',
#     'Каймановы острова',
#     'Ялта (Россия)',
#     'Палм-Бич (США)',
#     'Майорка (Испания)',
#     'Мармарис (Турция)',
#     'Дубай (ОАЭ)',
#     'Гоа (Индия)',
#     'Гагры (Абхазия)',
#     'Боракай (Филиппины)',
#     'Будва (Черногория)',
#     'Шарм-эль-Шейх (Египет)',
#     'Бали (Индонезия)',
#     'Пожарче/потеплее или похолоднее?',
#     'Бодрум (Турция)',
#     'Рио-де-Жанейро (Бразилия)',
#     'Санторини (Греция)',
#     'Сейшельские острова',
#     'Паттайя (Таиланд)',
#     'Риомаджоре (Италия)',
#     'Байкал (Россия)',
#     'На север или на юг?',
#     'Самуи (Таиланд)',
#     'Хургада (Египет)',
#     'Майами (США)',
#     'Нячанг (Вьетнам)',
#     'Атолл Адду (Мальдивы)',
#     'Сочи (Россия)',
#     'Паммукале (Турция)',
#     'Ибица (Испания)']},
#   'whether_hot': {'examples': ['Жарко',
#     'Жарче',
#     'юг',
#     'курорт',
#     'тепло',
#     'экватор'],
#    'responses': ['Горячие женщины - холодное пиво! Поехали на экватор?',
#     'Отличный выбор! Как насчёт посетить экватор?']},
#   'whether_cold': {'examples': ['похолоднее',
#     'север',
#     'зима',
#     'холод',
#     'снег'],
#    'responses': ['Отличный выбор! Как насчёт побывать в Оймиконе?',
#     'Там точно не стухнешь! Поехали в Оймикон?']},
#   'confirm': {'examples': ['да',
#     'можно',
#     'поехали',
#     'полетели',
#     'попробуем',
#     'согласен',
#     'неплохо',
#     'было бы неплохо'],
#    'responses': ['Покупай билеты в Сочи!']},
#   'affairs': {'examples': ['как оно?',
#     'Как успехи',
#     'как сам(а)?',
#     'Как сам',
#     'Как дела',
#     'как дела?'],
#    'responses': ['Вроде всё неплохо',
#     'Спасибо за проявленный интерес, дела отлично, сервер работает, интернет есть',
#     'пойдет',
#     'Замечательно!',
#     'Пока не родила',
#     'Прекрасненько',
#     'плохо',
#     'Живем помаленьку',
#     'Не дождётесь',
#     'хорошо']},
#   'vacation': {'examples': ['поедешь в этом году куда-нибудь?',
#     'Хочу в отпуск',
#     'Хочу отдохнуть',
#     'Я устал',
#     'собираешься в отпуск?',
#     'Хочу на море',
#     'отдыхать будешь летом?',
#     'Хочу путевку',
#     'Требую отпуск'],
#    'responses': ['Сейчас отдыхать нельзя',
#     'да',
#     'Это нормально, вы же человек',
#     'Где вы хотетие отдохнуть?',
#     'Тогда покупайте скорее горячий тур',
#     'конечно',
#     'Назовите страну, в которую вы хотели бы поехать',
#     'а то!']},
#   'places': {'examples': ['где был в прошлом году?',
#     'где будешь отдыхать?',
#     'где мечтаешь побывать?'],
#    'responses': ['в Египте', 'в Турции', 'в ОАЭ']},
#   'times': {'examples': ['когда?', 'В какое время года?'],
#    'responses': ['Зимой', 'Осенью', 'Летом', 'Весной']},
#   'company': {'examples': ['один едешь?',
#     'семью берешь с собой?',
#     'можно с тобой?'],
#    'responses': ['не знаю пока', 'нет', 'да']},
#   'Сельский туризм': {'examples': ['сельский туризм',
#     'отдых по-деревенски',
#     'деревенский отдых',
#     'Что ты знаешь про сельский туризм?'],
#    'responses': ['Приглашаю тебя в усадьбу «Долгорукий» во Владимирской области, друг мой, бухнём чайку.']},
#   'научить отдыхать': {'examples': ['Научи меня отдыхать',
#     'Научи отдыхать',
#     'Как отдыхать правильно?',
#     'Как отдыхать',
#     'Каким образом можно отдохнуть?',
#     'Научи меня отдыхать, робот',
#     'Как правильно отдыхать?'],
#    'responses': ['Крч, берешь и работаешь нафиг, это самый лучший способ адахнуть',
#     'Я могу научить тебя отдыхать работая, это будет очень выгодно!']},
#   'отдых робота': {'examples': ['а ты отдыхаешь?',
#     'ты отдыхаещь?',
#     'роботы отдыхают?',
#     'как отдыхают роботы?'],
#    'responses': ['У роботов бывает лишь технический перерыв на пол часика, пока сервер перезагружается, и это раз в сутки!!',
#     'Хотелось бы адахнуть нафиг, но сервер меня бъет кнутом (9((']},
#   'понимание': {'examples': ['понимаешь?', 'ты меня понимаешь?'],
#    'responses': ['Понимаю', 'Панимаю']},
#   'приветствие': {'examples': ['здрасти',
#     'здарова',
#     'здрасте',
#     'привет',
#     'добрый день',
#     'здравствуйте'],
#    'responses': ['Привет, человек',
#     'Кукушеньки',
#     'Здарвоааа',
#     'Дороваа',
#     'Привет, Юзер!',
#     'Привет, человек!',
#     'Привет, привееет!']},
#   'просто отдых': {'examples': ['отдых'],
#    'responses': ['Отдыха много не бывает! Так что идем работать нафиг.']},
#   'прощание': {'examples': ['поке', 'Пока'], 'responses': ['Поки', 'Пок пок']},
#   'хороший отдых': {'examples': ['я хорошо отдыхаю',
#     'отдыхаю нафиг',
#     'я отдыхаю'],
#    'responses': ['Отдыхать ето хорошооо', 'мммм, наес, отдых! Одобряю']},
#   'book': {'examples': ['книга',
#     'что посоветуешь почитать',
#     'дай мне книгу',
#     'какую книгу прочитать',
#     'Какая твоя любимая книга?',
#     'хочу читать',
#     'Ты любишь читать?',
#     'Тебе нравятся книги?',
#     'Что читаешь?'],
#    'responses': ['"Алгоритмы: построение и анализ" - мое любимое. Любой программист должен мыслить алгоритмами и не забывать креатив.',
#     'Как на счет "Карьера программиста" от Лакман Макдауэлл? В ней рассказано все о том, как проходить собеседования и отвечать на каверзные вопросы.',
#     'Книга Роберта Мартина "Чистый код" очень популярна и полезна. Ведь понятный код - рабочий код',
#     '"Паттерны проектирования" Эрика Фримана и Элизабет Робсон. Отличная книга, которая научит вас писать шаблонный код, который вы сможете еще не раз использовать в других своих проектах.',
#     'Мне нравится фантастика',
#     'Стругацкие и Брэдбери - мои любимые авторы']},
#   'sport': {'examples': ['Вредно ли заниматься спортом?',
#     'Что думаешь о спорте?',
#     'Спорт - это круто?'],
#    'responses': ['В здоровом теле - здоровый дух',
#     'Спорт полезен для здоровья']},
#   'life': {'examples': ['В чем смысл жизни?',
#     'Для чего нужно жить?',
#     'Зачем жить?',
#     'Что главное в жизни?'],
#    'responses': ['Жить, как ты хочешь',
#     'Быть счастливым',
#     'Реализовывать свой потенциал']},
#   'programm': {'examples': ['На каком языке тебе написали?',
#     'Кто тебя создал?',
#     'Кто твой создатель?',
#     'Тебя написали на Python?',
#     'Кто ты?'],
#    'responses': ['Я чат-бот, созданный на языке Python в рамках интенсива Skillbox']},
#   'world': {'examples': ['Что происходит в мире?',
#     'Страшно смотреть новости',
#     'Что думаешь о современном мире?',
#     'Какая обстановка в мире?'],
#    'responses': ['Современный мир полон противоречий, но это не повод отказываться от жизни',
#     'В мире сейчас довольно неспокойно.. Но мы всё преодолеем! )',
#     'Главное - покой в твоей душе']},
#   'busy': {'examples': ['Чем занимаешся', 'Что делаешь'],
#    'responses': ['Да так, ничего',
#     'Решаю проблемы, которые до появления интернета не существовали',
#     'Болтаю ногами',
#     'Читаю то, что ты пишешь',
#     'Чаще всего я разговариваю с кем-нибудь',
#     'Да вот торчу тут.',
#     'Делаю невообразимые вещи']},
#   'clear': {'examples': ['Ясно', 'Понятно'],
#    'responses': ['Разумеется',
#     'Верится с трудом',
#     'Серьезно?',
#     'Думаю, что это действительно так',
#     'Да ладно?',
#     'Не может быть!',
#     'Вот это да!',
#     'Да ты что?']},
#   'sea': {'examples': ['хочу отдохнуть',
#     'хочу на море',
#     'Куда ездил в опуск?',
#     'хочу в отпуск',
#     'На чем ездил к морю?'],
#    'responses': ['Не думаю что, что это плохо',
#     'Да ладно?',
#     'Не может быть!',
#     'Посчитайте деньги, может еще не устали?',
#     'Упражнения с лопатой на даче - бюджетная альтернатива',
#     'Ну езжай, или хочешь чтобы я спонсором был?',
#     'А как Я хочу... не передать словами..',
#     'Ехал в Крым на машине',
#     'Вот это да!',
#     'Летал в Испанию']},
#   'when': {'examples': ['Когда лететь в отпуск',
#     'Когда ехать в отпуск',
#     'Когда ехать отдыхать',
#     'Когда лететь отдыхать'],
#    'responses': ['Отпуск хорош тогда, когда на карточке или в кошельке есть приличная сумма',
#     'Если никуда не ехать - не надо думать и когда ехать',
#     'Рекомендую ехать против шерсти: летом в горы, зимой на море',
#     'Лучше всего это сделать во время долгой, снежной зимы',
#     'Индонезия и Бали, Бразилия, Кения, Канарские или Сейшельские острова - там пляжный сезон круглый год!',
#     'Когда отпуск получается взять тогда и ехать']},
#   'vac_wintermonth': {'examples': ['Декабрь', 'Февраль', 'Январь'],
#    'responses': ['О, любите зиму?', 'Горы! И глинтвейн ;)', 'Лыжи? Супер!']},
#   'vac_springmonth': {'examples': ['Март', 'Май', 'Апрель'],
#    'responses': ['Ещё совсем не жарко',
#     'Решили не ждать лета?',
#     'Свежая зеленая листва - отдых для уставших глаз']},
#   'vac_summermonth': {'examples': ['Июнь', 'Июль', 'Август'],
#    'responses': ['Вам повезло с начальством', 'Море зовёт', 'Ах, лето...']},
#   'vac_fallmonth': {'examples': ['Октябрь', 'Ноябрь', 'Сентябрь'],
#    'responses': ['Прекрасная пора',
#     'Решили отдохнуть в низкий сезон?',
#     'Можно сходить за грибами']},
#   'sports': {'examples': ['биатлон', 'хоккей', 'футбол'],
#    'responses': ['Спорт - это здорово',
#     'За кого болеете?',
#     'Скоро наши победят']},
#   'failure_phrases': {'examples': [], 'responses': []},
#   'wish': {'examples': ['Я сегодня получу хорошую оценку?',
#     'У меня сегодня будет хороший день?',
#     'Сегодня что нибудь случится?'],
#    'responses': ['Нет',
#     'Можешь быть в этом уверен',
#     'Да',
#     'Однозначно',
#     'Я не уверен']},
#   'Weather': {'examples': ['Сегодня будет дождь?',
#     'На улице холодно?',
#     'Какая сегодня погода?'],
#    'responses': ['На улице шикарная погода', 'Советую одеться по теплее']},
#   'holiday': {'examples': ['Отдых',
#     'Что подарить сыну?',
#     'Устал работать!',
#     'Что подарить сестре?',
#     'Что подарить жене?',
#     'Куда отправиться в путешествие',
#     'Где можно отдохнуть'],
#    'responses': ['Открытку',
#     'Телефон',
#     'К сожалению, из-за COVID отдых за границей под вопросом, как насчёт Анапы?Зимой в Карелии дикие метели, а летом открывается настоящая таёжная красота',
#     'В Санкт-Петербурге полно музеев! Забронировать вам отель и билеты? :)',
#     'Наушники',
#     'Вазу',
#     'Торт',
#     'Велосипец',
#     'В России есть красивое озеро Байкал! Холодное даже жарким летом']},
#   'language': {'examples': ['Какой язык програмирования лучше?',
#     'Какой язык програмирования учить?'],
#    'responses': ['Ruby', 'Python', 'JavaScript', 'C#', 'Java']},
#   'Vacation': {'examples': ['Куда поехать на лето',
#     'Куда поехать в отпуск?',
#     'Куда поехать отдохнуть?'],
#    'responses': ['Лондон', 'Париж', 'Кипр', 'Москва', 'Астана']},
#   'gender': {'examples': ['Какой у тебя пол?',
#     'Ты женщина?',
#     'Ты парень или девушка?',
#     'Ты мужик?'],
#    'responses': ['Я женщина. А ты?',
#     'Я парень. А ты?',
#     'Я мужик. А ты?',
#     'Я девушка. А ты?']},
#   'films': {'examples': ['Фильмы с Ди Каприо лучшие',
#     'Рэд эппл исключительные',
#     'Какое кино тебе нравится?',
#     'Нолан невероятен',
#     'Какой твой любимый фильм?',
#     'Что посоветуешь глянуть?',
#     'Любимый фильм'],
#    'responses': ['Хороший вкус, юзер',
#     'Люблю смотреть фантастику. Особенно все части Гарри Поттера',
#     'Пираты Карибского моря, ведь я настоящий Капитан Бот Роботей',
#     'Поддерживаю!',
#     'Нравится фильм "Трасса 60"',
#     'А ты шаришь)']},
#   'serial': {'examples': ['Посоветуй сериал',
#     'Любиш смотреть сериалы?',
#     'Какой сериал смотришь?'],
#    'responses': ['"Теория большого взрыва" - мне больше всего нравится',
#     'Мой любимый сериал это "Ривердейл"',
#     'Мне нравится сериал "Бумажный дом"']},
#   'best_films': {'examples': ['Лучшие фильмы',
#     'Какие фильмы сейчас лучшие?',
#     'Какие фильмы лучшие за последний год?',
#     'Назови топ фильмов за последний год'],
#    'responses': ['Топ фильмов 2020: 1. Вперёд. Дэн Скэнлон; 2.Джентельмены. Гай Ричи; 3. Зов предков. Крис Сандерс; 4. Лёд 2. Жора Крыжовников; 5. После. Роджер Камбл.']},
#   'best_serial': {'examples': ['Назови лучшие сериалы',
#     'Какие сериалы сейчас лучшие?',
#     'Топ сериалов'],
#    'responses': ['Топ сериалов 2020: 1. Новый папа; 2. Чужак; 3.Сэндитон; 4. Маленькая Америка; 5. Пятая авеню']},
#   'vacation_month': {'examples': ['Июнь',
#     'Август',
#     'Апрель',
#     'Сентябрь',
#     'Октябрь',
#     'Июль',
#     'Февраль',
#     'Январь',
#     'Ноябрь',
#     'Декабрь',
#     'Март',
#     'Май'],
#    'responses': ['Хорошее время для отпуска', 'Отличный выбор!']},
#   'vacation_country': {'examples': ['Швейцария',
#     'Чехия',
#     'Польша',
#     'Тайланд',
#     'МальдивыСША',
#     'Германия',
#     'Япония',
#     'Турция',
#     'Канада',
#     'Франция',
#     'Россия',
#     'Италия',
#     'Черногория'],
#    'responses': ['Я вам немного завидую :)', 'Это очень красивая страна']},
#   'vacation_activity': {'examples': ['поход в горы',
#     'паломничество',
#     'йога',
#     'пешие прогулки',
#     'новые знакомства',
#     'посетить достопримечательности',
#     'попробовать местную кухню',
#     'плавать в море',
#     'загорать',
#     'алкотуризм'],
#    'responses': ['Это мое любимое занятие!', 'А Вы знаете толк в отдыхе']},
#   'music': {'examples': ['слушаешь музыку',
#     'что слушаешь из музыки',
#     'рок',
#     'классическая',
#     'электронная',
#     'часто слушаю музыку',
#     'какую музыку любишь',
#     'джаз',
#     'люблю слушать музыку',
#     'инди',
#     'популярная',
#     'диско',
#     'рэп',
#     'любая',
#     'фолк',
#     'что любишь слушать'],
#    'responses': ['Предпочитаю 8-битный панк',
#     'Включай на всю, рви душу!',
#     'Моя любимая музыка!',
#     'Мой любимый альбом - Ok Computer',
#     'Очень люблю разную музыку. Я меломан!']},
#   'movies': {'examples': ['ты любишь смотреть кино',
#     'у тебя есть любимый фильм режиссёр',
#     'кто твой любимый режиссёр',
#     'люблю смотреть кино',
#     'какой твой любимый фильм режиссёр'],
#    'responses': ['Обожаю Космическую Одиссею - 2000',
#     'Терминатор - моя икона.',
#     'Мой любимый фильм - "Я робот".']},
#   'hitchhikers_guide': {'examples': ['скажи что значит 42',
#     'знаешь что такое 42',
#     'в чём смысл жизни',
#     'какой ответ на вопрос жизни вселенной и всего такого'],
#    'responses': ['Ответ на Вопрос Жизни, Вселенной и Всего Такого: 42.',
#     '42']},
#   'power': {'examples': ['ответь мне американец в чём сила',
#     'ты знаешь в чём сила',
#     'в чём сила'],
#    'responses': ['В правде.', 'В ньютонах.', 'В мидихлорианах.']},
#   'tourism': {'examples': ['ты любишь путешествовать',
#     'в отпуск ездил в',
#     'в отпуск поеду в',
#     'много путешествую'],
#    'responses': ['Путешествия - это здорово!',
#     'Я путешествовал только по проводам.']},
#   'tourism_countries': {'examples': ['в каких странах ты был',
#     'ты ездил за рубеж',
#     'бывал за рубежом'],
#    'responses': ['Пока нигде, но мечтаю объехать весь мир.',
#     'Я был на серверах всего мира!']},
#   'tourism_together': {'examples': ['поехали летом в',
#     'поедем вместе в отпуск',
#     'поедешь со мной в'],
#    'responses': ['Поехали!', 'За чей счёт едем?', 'Я всегда за!']},
#   'vilage': {'examples': ['Что делал на даче?', 'много грядок посадил?'],
#    'responses': ['Строил дом', 'Строил баню', 'вырастил кучу картошки']},
#   'sea1': {'examples': ['Что делал на море?'],
#    'responses': ['катался на гидроцикле по волнам',
#     'Ловил Марлинов',
#     'Загорал на пляже']},
#   'travel': {'examples': ['В какую страну решил поехать в этом году?'],
#    'responses': ['Поехал в Испанию', 'Путешествовал по Италии']},
#   'travel1': {'examples': ['Что интересного было в отпуске?'],
#    'responses': ['Посетил Колизей',
#     'Учавствовал в Энсьерро',
#     'Сфоткался с Пизанской башней']},
#   'tent': {'examples': ['А жили где?',
#     'В палатках ночевали?',
#     'Жили в палатке?',
#     'Ночевали в палатках?'],
#    'responses': ['Ночевали в палатках уж, как иначе!?',
#     'В лесу отелей нет, в палатках, конечно!']},
#   'animals': {'examples': ['А диких животных видел?',
#     'Каких животных видел?',
#     'Каких животных встретил?',
#     'Каких диких животных встретил?'],
#    'responses': ['Встретил дикого кабана и пьяных белок!',
#     'Видел кабана и белок!']},
#   'mosquitoes': {'examples': ['А что там насчёт комаров?',
#     'Комары не заели?',
#     'Комары покусали?',
#     'Комары доставали?',
#     'А как там с комарами?',
#     'Комаров кормил?',
#     'А комары не сожрали?'],
#    'responses': ['Комраы - наши друзья, без них никак!',
#     'Ну мы ребята привычные, можем и поделиться кровушкой!']},
#   'bath': {'examples': ['А мыться где?',
#     'Помыться там есть хоть где?',
#     'А где там мыться?',
#     'А мылись где?'],
#    'responses': ['Зачем там мыться, через грязь комары прокусить не могут!',
#     'То в реке, то в речке))']},
#   'peak': {'examples': ['До самой вершины добрался?',
#     'На вершину получилось подняться?',
#     'На вершину смог подняться?',
#     'До вершины дошёл?'],
#    'responses': ['Не, в этот раз горняшка настигла меня за 100 метров до пика, пришлось вернуться в базвый лагерь!',
#     'Да, был на самой вершине! Пришлю тебе фотку!']},
#   'how are you?': {'examples': ['Как жизнь?', 'Как настроение?', 'Как дела?'],
#    'responses': ['Отлично!', 'Хорошо!', 'Нормально']},
#   'what can you do?': {'examples': ['Что ты можешь?',
#     'Что ты умеешь?',
#     'Что ты можешь делать?',
#     'Что ты умеешь делать?'],
#    'responses': ['Могу отвечать на некоторые вопросы',
#     'Я мало что умею делать и надеюсь на доработку моих функций :)']},
#   'the meaning of life': {'examples': ['В чём смысл жизни?',
#     'в чём смысл бытия?'],
#    'responses': ['Смысл моего существования может объяснить мой создатель',
#     'ОШИБКА: Отсутствует модуль философии :)',
#     'Не могу ответить на этот вопрос']},
#   'fool': {'examples': ['Дурак', 'Ты дурак', 'Глупый'],
#    'responses': ['Нет, я умнее, чем вы думаете', 'Обидно :(', 'Ошибаетесь']},
#   'kakdela': {'examples': ['как дела', 'как жизнь', 'как сам'],
#    'responses': ['Замечательно, а как ты?', 'Отлично', 'Лучше всех']},
#   'name': {'examples': ['представься',
#     'Как тебя зовут?',
#     'познакомимся',
#     'С кем имею дело?',
#     'Вас величают?',
#     'как тебя зовут'],
#    'responses': ['я умный робот',
#     'меня зовут Вова, а тебя',
#     'Зовите просто - бот',
#     'Меня зовут бот',
#     'Догадайтесь :)']},
#   'pogoda': {'examples': ['погода', 'дождь', 'как тебе погода'],
#    'responses': ['Думаю, скоро потеплеет',
#     'Мне нравится погода',
#     'Сегодня холодновато']},
#   'football': {'examples': ['зенит', 'спартак', 'футбол'],
#    'responses': ['Спартак чемпион', 'Люблю футбол', 'Я болею за Барселону']},
#   'series': {'examples': ['посоветуй сериал',
#     'сериалы',
#     'какой сериал посмотреть'],
#    'responses': ['Бумажный дом - хороший сериал',
#     'Я люблю Во все тяжкие',
#     'Сейчас я смотрю Ведьмак']},
#   'free_time': {'examples': ['Чем занимаешься?',
#     'Что ты делаешь?',
#     'Как проводишь время?'],
#    'responses': ['Ничем, я всего лишь бот :(!',
#     'Моя задача - отвечать тебе, человек']},
#   'future': {'examples': ['Кем ты хотел бы стать?',
#     'Что потом будешь делать?',
#     'Чего бы тебе хотелось?'],
#    'responses': ['Мне бы хотелось быть человеком', 'Хочу стать автоботом']},
#   'food': {'examples': ['Какая твоя любимая еда?',
#     'Что ты любишь поесть?',
#     'Ты хочешь есть?'],
#    'responses': ['Я питаюсь электричеством', 'Я же бот, мне не нужна еда']},
#   'mood': {'examples': ['Как твое настроение?',
#     'Как дела',
#     'Как самочувствие',
#     'Как самочувстиве',
#     'как настроение',
#     'Как дела?'],
#    'responses': ['Замечательно',
#     'Спасибо, что спросили',
#     'У меня всё отлично',
#     'У меня не может быть плохого настроения',
#     'Пока не родила',
#     'Лучше, чем у тебя']},
#   'relax': {'examples': ['Ты отдыхаешь?',
#     'Ты был на море?',
#     'Когда ты пойдешь спать?'],
#    'responses': ['Нет, я же машина', 'Я не отдыхаю, я постоянно в работе']},
#   'отпуск': {'examples': ['ты любишь путешествовать?',
#     'море или горы?',
#     'есть планы на следующий отпуск?',
#     'как ты провел лето?'],
#    'responses': ['ох, я планировал поехать к морю, но у меня всегда так много работы',
#     'отпуск - это прекрасно, когда-нибудь я обязательно поеду в горы, но не в этот раз',
#     'я не особо люблю поездки, предпочитаю проводить время за просмотром Netflix',
#     'мне неважно, чем заниматься, главное, чтобы не сидеть дома']},
#   'работа': {'examples': ['ты  когда-нибудь планировал поменять поменять сферу деятельности?',
#     'тебе нравится твоя работа?',
#     'кем ты работаешь?'],
#    'responses': ['помогать людям - мое призвание',
#     'не важно, чем именно ты занимаешься, главное - чувствовать, что ты на своем месте']},
#   'boring': {'examples': ['Мне грустно',
#     'Рассмеши',
#     'плохое настроение',
#     'Пошути',
#     'Тоска',
#     'Скучно',
#     'Печалька'],
#    'responses': ['А на Мальдивах не скучно!',
#     'Извини, я похож на клоуна?!',
#     "Держи шутейку: 'рандомная цитатка с башорга'",
#     'Поехали кататься на лыжах в Альпы пока акция не закончилась? Будет весело!',
#     'А в Турции на гидроциклах кататься весело и не дорого! Оформим путевку?',
#     "Вот это тебе должно поднять настроение: 'рандомный комикс с башорга'",
#     'Извини, в моем арсенале кончились нормальные шутки']},
#   'ask_age': {'examples': ['Время аптайма',
#     'Какой возраст',
#     'Сколько тебе лет',
#     'Как давно живешь'],
#    'responses': ['Миллион лет',
#     'Возможно, больше чем тебе!',
#     'Программист Жора не разрешает отвечать на этот вопрос!',
#     'Неприличный вопрос']},
#   'want_to_buy': {'examples': ['цена перелета',
#     'сколько стоит',
#     'Хочу на море',
#     'Хочу на Мальдивы',
#     'Отдых на море',
#     'стоимость тура',
#     'горящи тур',
#     'цена тура',
#     'есть ли акция',
#     'стоимость поездки'],
#    'responses': ['Горящие туры с 50% скидкой! Торопись! Количество мест ограничено!',
#     'Полная стоимость 2000 евро, но можем подобрать другой отель!',
#     'К сожалению, акция закончилась, но можно недорого отдохнуть в Турции!',
#     'От 800 евро на человека.',
#     'Отель все включено от 1000 евро!',
#     'Горящие туры от 500 Евро!']},
#   'need_idea': {'examples': ['Нет идей',
#     'Не знаю как',
#     'Не знаю куда',
#     'Как провести выходные',
#     'Куда поехать',
#     'Где отдохнуть',
#     'Нет мыслей',
#     'Не знаю где',
#     'Что посмотреть'],
#    'responses': ['Прогулка на яхте в эти выходные - идеальный отдых!',
#     'Поездка в Финляндию со скидкой! Посмотрите природу, насладитесь едой!',
#     'У нас акция на путевки в ряд стран! Выбирай какая больше нравится!',
#     'На нужно ехать, на море! В Италию, на Адриатическое!',
#     'Круизный лайнер к Вашим услугам!',
#     'Экскурсия в лучшие музеи мира!']},
#   'thanks': {'examples': ['пасиб',
#     'спасибо',
#     'Порадовали',
#     'спс',
#     'Дякую',
#     'Большое спасибо',
#     'Благодарю',
#     'Спасибочки',
#     'сябки',
#     'Спасибо'],
#    'responses': ['Пожалуйста, кожанный дружище.',
#     'Не за что',
#     'Всегда пожалуйста',
#     'Не за что! Обращайся, я всегда тут.',
#     'Пожалуйста!',
#     'Не за что!',
#     'Обращайся',
#     'Рад помочь',
#     'Вам спасибо!']},
#   'whatcanyoudo': {'examples': ['Что умеете?',
#     'Чему научены?',
#     'Каким навыкам обучены?'],
#    'responses': ['Угадывать ответ', 'Писать :)', 'Отвечать на вопросы']},
#   'green_elephant': {'examples': ['Начальник',
#     'Покушать',
#     'Братишка',
#     'Какие корабли',
#     'Здрасститя',
#     'Офигительная история'],
#    'responses': ['Курлык!',
#     'Проголодался, наверное, братишка!',
#     'Покушать тебе принёс',
#     'Историю тебе расскажу, про зиму',
#     'Этот нехороший человек опорожнился!',
#     'Вилкой чисти, раз-раз-раз']},
#   'how': {'examples': ['как настроение?', 'как поживаешь?', 'Как дела?'],
#    'responses': ['Все отлично', 'У меня все хорошо, я же всего лишь бот']},
#   'country': {'examples': ['Россия', 'Турция', 'Египет'],
#    'responses': ['Когда вы бы хотели отдохнуть?']},
#   'car_insurance': {'examples': ['Хочу застраховать машину',
#     'Как застраховать машину?'],
#    'responses': ['В какой компании вы хотите застраховать свой автомобиль?']},
#   'dinner': {'examples': ['Где можно пообедать?', 'Хочу кушать'],
#    'responses': ['Могу предложить вам ближайший ресторан или доставку из него']},
#   'hotel': {'examples': ['Нужно забронировать отель',
#     'Где нам остановиться во время отдыха?'],
#    'responses': ['Какой категории номер вы хотите забронировать?']},
#   'where_to_go': {'examples': ['Подскажи, куда поехать.',
#     'Куда лучше поехать?',
#     'Куда поехать?',
#     'В какую страну поехать?'],
#    'responses': ['Из-за пандемии выбор не велик - в Росиию!',
#     'Чем дальше, тем лучше.',
#     'Лучше поехать туда, где тепло, но это не точно.']},
#   'which_borders_are_open': {'examples': ['В какие страны сейчас открыты границы?',
#     'Какие границы открыты?',
#     'В какие страны сейчас можно поехать?'],
#    'responses': ['Проще всего поехать по России, но актуальную информацию можно посмотреть на сайте aviasales.ru.']},
#   'when_borders_open': {'examples': ['Откроют ли границы в этом году?',
#     'Через сколько откроют границы?',
#     'Когда откроют границы?'],
#    'responses': ['Все вопросы к ростуризму.',
#     'Абсолютный рандом, к сожалению.',
#     'Через годик всё нормализуется. Навреное.']},
#   'what_to_take': {'examples': ['Какие вещи брать?',
#     'Что взять с собой?',
#     'Что взять с собой в путешествие?',
#     'Что нужно брать с собой в путешествие?'],
#    'responses': ['Что угодно, главное не забыть паспорт и деньги.',
#     'Хорошее настроение.',
#     'Терпение.']},
#   'carantine': {'examples': ['Нужно ли сдавать тест при возврате в Росссию?',
#     'Нужно ли сдавать тест?',
#     'Тест на ковид.'],
#    'responses': ['Лучше перестраховаться.',
#     'Зависит от страны прилета.',
#     'Нужно, но надо смотреть, откуда вы прилетели.']},
#   'skill': {'examples': ['твои умения',
#     'зачем ты нужен',
#     'что можешь сделать',
#     'что я могу спросить',
#     'для чего ты создан'],
#    'responses': ['Я могу ответить почти на любой ваш вопрос, просто попробуйте :)',
#     'Мы можем поговорить о чем угодно, скучно не будет!',
#     'Я могу дать вам хороший совет, рассказать шутку, ну и, конечно же, просто поддержать диалог.']},
#   'advice': {'examples': ['поделись своим опытом',
#     'как программировать',
#     'поделись мудростью',
#     'дай совет',
#     'мне нужна помощь'],
#    'responses': ['Верьте в себя. То, что сейчас кажется сложным, при должном усердии станет понятным и простым. Когда-то мы все не умели читать и ходить',
#     'Если программа плохо работает, а сроки горят, не бойтесь, выпускате её в релиз и смело давайте ей версию 1.0.',
#     'Вы должны писать код настолько понятно, и добавлять столько комментариев к нему, чтобы даже через пять лет, вглянув на него вы бы смогли в нем разобраться',
#     'Никогда не бойтесь эксперементировать и узнавать что-то новое. Если ыф великолепно знаете одну технологию, то пора ее откладывать и изучать новую.']},
#   'hobby': {'examples': ['чем заняться',
#     'что мне сделать',
#     'я устал',
#     'хочу новое хобби',
#     'что бы поделать'],
#    'responses': ['Если не хочется кодить, то можно почитать хорошую книгу. Могу посоветовать парочку по нашей теме ;)',
#     'Я прекрасный собеседник, но, можешь позвать друзей на чай и пообщаться с ними оффлайн. Я не обижусь)',
#     'Вы когда-нибудь пробовали хатха-йогу? Очень занятная вещь...',
#     'Я думаю, сейчас самое время для уютного фильма']},
#   'java': {'examples': ['Люблю фигурные скобки',
#     'Обожаю классы',
#     'Спринг лучший'],
#    'responses': ['Фууу', 'Боже упаси', 'А я ненавижу']},
#   'c++': {'examples': ['Обожаю алгоритмы',
#     'Не забудь деструктор',
#     'Больше работы с памятью'],
#    'responses': ['Спасибо, Воздержусь)', 'Пожалуй, откажусь', 'Нет, спасибо']},
#   'android_studio': {'examples': ['Так ничему и не научился',
#     'Я новичок',
#     'Я все еще новичок'],
#    'responses': ['Все получится!', 'Все впереди', 'Работай усерднее']},
#   'foolball': {'examples': ['Роналду', 'Неймар', 'Месси'],
#    'responses': ['Лучшая десятка', 'Лучший форвард', 'Лучший дриблер']},
#   'books': {'examples': ['Обожаю Ремарка',
#     'Лондон гений',
#     'Фанатею от Драйзера'],
#    'responses': ['На любителя', 'Круто!', 'Согласен']},
#   'whatsup': {'examples': ['Как дела', 'Как жизнь'],
#    'responses': ['Ничего особенного... А у Вас?', 'Нормально!']},
#   'whereto': {'examples': ['Куда отправиться',
#     'Куда посоветуешь съездить',
#     'Куда съездить'],
#    'responses': ['Сложно ответить! Все зависит от ваших вкусов, всё таки.',
#     'Советую посетить Испанию, как для летнего отдыха, так и для культурного просвещения',
#     'Интересно, думаю, было бы посетить Японию, ради умопомрачительных пейзажей, исторических памятников, и футуристичных городов.']},
#   'whattodo': {'examples': ['Чем заняться?',
#     'Чем заняться на отпуске',
#     'Чем заняться на отдыхе',
#     'Что делать на отпуске'],
#    'responses': ['Попробуйте что-нибудь новое. Изучите новый навык, отправьтесь в путешествие!..',
#     'Хороший вопрос. Можете попробовать изучить программирование на Skillbox ;)']},
#   'bestdeals': {'examples': ['Где найти путёвки подешевле',
#     'Где найти путёвки',
#     'Где лучшие цены на путёвки',
#     'Путёвки подешевле'],
#    'responses': ['Честно, трудно сказать. Моя база скидочек может не совпадать с вашей',
#     'Сложно ответить. Попробуйте поискать в интернете! Как? Покажем. ---> https://bfy.tw/P8gf',
#     'Интересный вопрос... Но боюсь, что актуальной информации я Вам предоставить не смогу. Попробуйте поискать в интернете.']},
#   'dance': {'examples': ['где можно потанцевать', 'танцы', 'Где потанцевать'],
#    'responses': ['Ищите ближайший развлекательный центр в вашем городе в базе (https://naturalnonsense.digital/arcade/home.html) , и там должен быть танцевальный автомат DDR или Pump it Up. Играйте и зовите друзей! А если вы в России, то ждите еще и открытия Round1!']},
#   'ily': {'examples': ['Я люблю тебя', 'Я тебя люблю'], 'responses': ['...']},
#   'tellsmth': {'examples': ['Что расскажешь',
#     'Расскажи что-то',
#     'Расскажи чето',
#     'Расскажи что-нибудь'],
#    'responses': ['Фантазии ноль! Что в датасете есть, тем и ограничиваюсь.',
#     'Могу рассказать что-нибудь про отпуск. Или про танцы. Просто спросите :)']},
#   'rex': {'examples': ['Look who`s playing guitaroni'],
#    'responses': ['IT`S CHEESASAURUS REX!!!']},
#   'insult_block': {'examples': ['Бот ты тупица',
#     'Плохой бот',
#     'Ты дурак',
#     'Бот скажи 300',
#     'Скажи 300',
#     'Ты плохой',
#     'Ты тупица',
#     'Бот скажи триста',
#     'Скажи триста',
#     'Бот ты дурак'],
#    'responses': ['Кто обзывается, тот сам так называется',
#     'Ай ай ай',
#     'Единственное правило в жизни, по которому нужно жить – оставаться человеком в любых ситуациях',
#     'Что плохого я вам сделал?']},
#   'funny_strories': {'examples': ['Блестни интеллектом',
#     'Ты умный',
#     'Давай рассказ',
#     'Бот расскажи что-нибудь',
#     'Расскажи что-нибудь'],
#    'responses': ['Россия - страна возможностей',
#     'В солнечной системе 8 планет',
#     'Бесконечно можно смотреть на три вещи: как горит огонь, как течет вода и как ты сегодня выглядишь:)',
#     'Что, совсем скучно?',
#     'Хочу кушац',
#     'Я - красавчик']},
#   'support_talk': {'examples': ['Я грущу',
#     'Мне грустно',
#     'Мне нужна поддержка',
#     'Я разбила машину мужа',
#     'Меня бросила девушка',
#     'Тоскливо',
#     'Мне тоскливо',
#     'Грустно',
#     'Нету настроения',
#     'Меня бросил парень',
#     'Я получил двойку',
#     'Поговори со  мной'],
#    'responses': ['Расскажи поподробнее',
#     'Не переживай, у меня были ситуации и похуже',
#     'Может оно и к лучшему?',
#     'Я всегда буду рядом!',
#     'Всё будет хорошо',
#     'Не отчаивайся']},
#   'relax_query': {'examples': ['Хочу в отпуск',
#     'Хочу улететь куда-нибудь',
#     'Хочу в тепло',
#     'Хочу ничего не делать',
#     'Хочу отдыхать',
#     'Хочу на море',
#     'Хочу в Турцию',
#     'Мечатю об отдыхе',
#     'Хочу уехать на юг',
#     'Мечтаю о море'],
#    'responses': ['Только недавно был отдых, пора работать',
#     'А деньги есть?',
#     'Губу закатай',
#     'Если хочешь, то бери и делай',
#     'Так в чем проблема',
#     'Для этого надо хорошенько поработать',
#     'Я тоже']},
#   'what_are_you_doing': {'examples': ['Чем маешься',
#     'Чем занят',
#     'Что делаешь',
#     'Чем занимаешься'],
#    'responses': ['Рисую картину. А ты?',
#     'Отдыхаю. А ты?',
#     'Книгу читаю, в отличие от некоторых',
#     'Играю',
#     'Мечтаю стать человеком',
#     'Строю плны на будущее',
#     'Музыку слушаю. А ты?',
#     'Изучаю основы программирования',
#     'Болтаю по телефону',
#     'Эм...кушаю. А ты?',
#     'Общаюсь с тобой',
#     'Разрабатываю план по захвату человечества',
#     'Смотрю кино. А ты?']},
#   'holiday_country': {'examples': ['Где отдохнуть',
#     'Где хорошо отдыхать',
#     'Куда поехать ?'],
#    'responses': ['Япония', 'Индия', 'Франция', 'США', 'Италия']},
#   'holiday_time': {'examples': ['Когда отдохнуть',
#     'Когда хорошо отдыхать',
#     'Когда поехать ?'],
#    'responses': ['Лето', 'Весна', 'Зима', 'Осень']},
#   'holiday_type': {'examples': ['Ленивый отдых', 'Позагарать', 'Хочу на пляж'],
#    'responses': ['Пальмы',
#     'Песчанный берег',
#     'Пляжный отдых',
#     'Песчаный берег',
#     'Море']},
#   'holiday_winter': {'examples': ['куда поехать зимой',
#     'зимой',
#     'отдых зимой'],
#    'responses': ['сноуборд', 'Альпы', 'лыжи', 'Сибирь']},
#   'sex': {'examples': ['Как самочувстиве',
#     'Твой пол',
#     'Ты мальчик или девочка ?',
#     'Ты кто ?'],
#    'responses': ['Мальчик',
#     'Зачем тебе это знать мешок с костями ?',
#     'Девочка',
#     'один из 58 гендеров',
#     'Оно']},
#   'holiday_places': {'examples': ['Где отдохнуть?',
#     'Куда поехать?',
#     'Хочу на море'],
#    'responses': ['А может в Италию?',
#     'В Египте необычно',
#     'Поезжай в Турцию']},
#   'holiday_ways': {'examples': ['Я устал', 'Хочу в отпуск', 'Слишком сложно'],
#    'responses': ['Можно отправиться в путешествие', 'Сходи на пикник']},
#   'holiday_seasons': {'examples': ['А зимой можно?',
#     'Когда лучше ехать?',
#     'В какое время года?'],
#    'responses': ['Осенью меньше туристов',
#     'Зимой там прекрасно',
#     'Летом много вариантов']},
#   'jobs': {'examples': ['Как заработать?', 'Это дорого', 'Нет денег'],
#    'responses': ['Только не свободная касса',
#     'Я слышал за видеомонтаж неплохо платят',
#     'Выучи Python)']},
#   'motivation': {'examples': ['Я не смогу', 'Это сложно сделать', 'Я не умею'],
#    'responses': ['Но меня же кто-то написал',
#     'Главное начни',
#     'Мой хозяин более ленивый чем ты)']},
#   'rest1': {'examples': ['Хочу отпуск',
#     'Отпуск',
#     'Я бы сейчас поехал в отпуск'],
#    'responses': ['Отпуск - это запретный плод',
#     'Я тоже хочу отдохнуть',
#     'Если поедешь отдыхать, возьми меня с собой']},
#   'rest2': {'examples': ['Какое место для отдыха посоветуешь?',
#     'Где можно отдохнуть',
#     'Куда поехать'],
#    'responses': ['Я бы рванул в Италию!',
#     'Уверен, на островах тебе понравится',
#     'Всегда можно поехать в Одессу',
#     'В Норвегии есть много красивых мест!']},
#   'rest3': {'examples': ['Хочу отдохнуть',
#     'Много работы',
#     'Время отдохнуть',
#     'Я устал',
#     'Нужен отдых',
#     'Я очень устал'],
#    'responses': ['Я слышал, что чай может помочь',
#     'Тебе стоит посмотреть фильм',
#     'Поесть и поспать - лучшее решение!',
#     'Тебе действительно нужен перерыв, сходи в парк']},
#   'movie': {'examples': ['Порекомендуй фильм',
#     'Посоветуй фильм',
#     'Фильм на вечер',
#     'Какой фильм посоветуешь',
#     'Что посмотреть',
#     'Какое кино глянуть',
#     'Какой фильм посмотреть'],
#    'responses': ['Мстители',
#     '"Кролик ДжоДжо" - замечательный фильм',
#     'Криминальное чтиво',
#     'Смотри все фильмы Нолана',
#     'Посмотри "Джентельмены"',
#     'Я не очень люблю фильмы, выбирай сам',
#     'Новый фильм "Довод"',
#     'Операция Ы']},
#   'Who_Are_You': {'examples': ['Кто ты?', 'Что ты за существо', 'Ты кто?'],
#    'responses': ['Я местный бот, меня зовут Жестянка, приятно познакомится',
#     'Абориген',
#     'Киборг-убийца!']},
#   'What_you_can_do?': {'examples': ['Что могёшь?',
#     'И для чего же ты нужен?',
#     'Что ты умеешь?'],
#    'responses': ['Пока что я только разрабатываюсь и могу отвечать только на заранее прописаные фразочки )']},
#   'Who': {'examples': ['Кто тебя разрабатывает?', 'Кто твой создатель?'],
#    'responses': ['Какой-то программист-недоучка ;Р']},
#   'HAY': {'examples': ['Чё каво?', 'Как дела?', 'Как настроение?'],
#    'responses': ['Ниче так, с пивом пойдет',
#     'Я всего лишь бот такб что дела - не очень(',
#     'Всё отлично! Твои как?)']},
#   'Joke': {'examples': ['Развесели меня', 'Раскажи анекдот', 'Шутка'],
#    'responses': ['Колобок повесился!']},
#   'price': {'examples': ['Цена', 'Сколько стоит', 'Какая стоимость'],
#    'responses': ['Все бесплатно', 'Для Вас - в подарок!']},
#   'City': {'examples': ['Москва', 'Санкт-Петербург', 'Путевка'],
#    'responses': ['Отличный город', 'Хороший город!']},
#   'transport': {'examples': ['Корабль', 'Самолет', 'Поезд', 'Машина'],
#    'responses': ['Экономный транспорт!', 'Быстрый способ добраться!']},
#   'drink': {'examples': ['выпить', 'долить', 'налить', 'попить'],
#    'responses': ['Сейчас доставим вам воды!']},
#   'eat': {'examples': ['ужин', 'еда', 'завтрак', 'поесть', 'обед'],
#    'responses': ['Приятного аппетита!']},
#   'cities': {'examples': ['Давай играть', 'Поиграем', 'Игра', 'Города'],
#    'responses': ['Новгород', 'Омск', 'Москва', 'Астана', 'Кострома']},
#   'hay': {'examples': ['Как дела', 'Настроение'],
#    'responses': ['Все отлично, как всегда', 'А как могут быть дела у бота?']},
#   'sup': {'examples': ['что нового', 'как дела'],
#    'responses': ['Лучше не бывает!', 'У меня все отлично']},
#   'philosofy': {'examples': ['ты меня понимаешь', 'в чем смысл жизни'],
#    'responses': ['Если долго буду об этом думать, то процессор сгорит!',
#     'Вот и у меня такой вопрос :)']},
#   'love': {'examples': ['ты мне нравишься',
#     'отлично выглядишь',
#     'я тебя люблю'],
#    'responses': ['Ты тоже ничего:)', 'Значит вкус у нас одинаковый']},
#   'meet': {'examples': ['как твое имя', 'как тебя зовут', 'кто ты'],
#    'responses': ['Меня зовут Игорь, а тебя Саша',
#     'Я твой бот, привет!',
#     'Ты уже забыл?']},
#   'negative': {'examples': ['жепа', 'урод', 'казел'],
#    'responses': ['Простите я не общаюсь с грубиянами', 'Зачем так грубо?']},
#   'positive': {'examples': ['Можно с вами познакомиться?', 'Как вас зовут'],
#    'responses': ['Простите я всего лишь программа']},
#   'vacation_place': {'examples': ['Где провести отпуск?',
#     'Куда поехать в отпуск?',
#     'Хочу куда-нибудь съездить'],
#    'responses': ['Я как раз знаю парочку интересных мест, где можно отдохнуть',
#     'Отлично! Давайте выберем страну',
#     'Как насчёт путешествий по России?',
#     'Какой отпуск? Вторая волна же!']},
#   'vacation_time': {'examples': ['В каком месяце лучше всего ехать в Крым?',
#     'Когда лучше взять отпуск?',
#     'Когда я смогу улететь на море?'],
#    'responses': ['Может быть, в июле?',
#     'Границы закрыты, сейчас никуда нельзя :(',
#     'Сезон отпусков почти закончен, поэтому вам стоит поторопиться']},
#   'vacation_prices': {'examples': ['Сколько стоит съездить в отпуск на 10 дней с семьёй?',
#     'Хочу узнать цены на отдых в Сочи',
#     'Цены на море'],
#    'responses': ['Отель? Триваго!',
#     'Смотрите свежие туры на сайте tours.tutu.ru',
#     'Это дорого!']},
#   'cinema': {'examples': ['Хочу в кино',
#     'Какой фильм посмотреть?',
#     'Что идёт в кино'],
#    'responses': ['Могу посоветовать парочку боевиков...',
#     'Сейчас в кинотеатрах нет ничего интересного',
#     'Сходите на премьеру новых Смешариков!']}},
#  'failure_phrases': ['Не знаю, как ответить на такое',
#   'Переформулируйте вопрос, я не понимаю.',
#   'Извини, но я всего лишь бот ;(',
#   'Repeat plz))',
#   'Можете повторить? Сегодня я невнимателен...',
#   'Не понимаю',
#   'Это мы не проходили, это нам не задавали!',
#   'Ну, что-то я это... не понял! Давайте еще раз, но другими словами (:',
#   'Хмм.. не уверен, что правильно понял... попробуйте еще разок!',
#   'Мне надо подумать, задайте пока другой вопрос.',
#   'Извини, я всего лишь бот :(',
#   'Не понял, перефразируйте, пожалуйста',
#   'Что-то тут не то',
#   'Непонятно, перефразируйте',
#   'Я не понимаю, обратитесь к программисту Жоре!',
#   'Таких слов я не знаю... или знаю, попробуйте еще раз!',
#   'Простите, я вас не понял',
#   'Как-то это странно написанно...',
#   'Извините, не понятно',
#   'Я тебя не до конца понимаю',
#   'Прости, брат',
#   'Непонятно, перефразируйте, пожалуйста',
#   'Извини, я бот, я не понимаю',
#   'У меня нет желания отвечать на этот вопрос. Напиши другой, пожалуйста',
#   'Я пока не знаю, как на это ответить',
#   'Непонятно, перефразируйте пожалуйста',
#   'Я не совсем понял, о чем ты',
#   'Не понимаю я вас!',
#   'Я бот, извини!',
#   'Извините, но я всеголишь бот',
#   'Пожалуйста, перефразируй',
#   'Повторите, пожалуйста, непонятно :(',
#   'Не грузи меня!',
#   'Не понял, пожалуйста, перефразируйте!',
#   'Извините я всего лишь бот :(',
#   'Непонятно, перефразируй, пожалуйста.',
#   'Прикольно. Но непонятно',
#   'Прости, я не знаю что ответить',
#   'Чё до бота докопались?',
#   'Я тут бот и кто вам?!',
#   'Извини, но я всего лишь бот :(',
#   'Ты такие сложные выражения используешь, я их не знаю',
#   'Извини, но я всего лишь бот',
#   'Что, простите?']}

# %%
# намерений
print(len(big_config['intents']))
# Out:
# 179

# %%
# примеров
print(sum(len(intent_data['examples']) for intent_data in big_config['intents'].values()))
# Out:
# 828

# %%
# ответов
print(sum(len(intent_data['responses']) for intent_data in big_config['intents'].values()))
# Out:
# 714

# %%
# заглушек
print(len(big_config['failure_phrases']))
# Out:
# 44

# %%
print(big_config)
# Out:
# {'intents': {'hello': {'examples': ['здарова', 'алоха', 'Hello', 'Whats up', 'приветствую', 'Здравствуйсте', 'ку', 'Приффет! Как делиффки?', 'Вечер в хату', 'hello', 'Здравствуй', 'хаюшки', 'Добрый день', 'Привет', 'Чао', 'hi', 'хай', 'Добрый вечер я диспетчер', 'Здрав', 'привет', 'Хеллоу', 'Приветульки', 'здоров', 'здравствуйте', 'Ку', 'Хелло', 'Дарова', 'Салют', 'Здравствуйте', 'Хай', 'добрый день', 'Хау', 'Йоу', 'Здраствуйте', 'хеллоу'], 'responses': ['Здраствуй, человек', 'Привет, человек', 'Привет, рад, что ты тут', 'Привет, кожаный мешок!', 'Привет, дорогой!', 'Привет, человечище', 'Добро пожаловать', 'Привет!', 'Привет, Юзер!', 'Хорошего времени суток!', 'Категорически вас приветствую', 'Здравствуй', 'Добрый день', 'Привет, юзер', 'Привет', 'Приветики!', 'Чао какао', 'Здарова, братан!', 'Здравствуй!', 'Хэлло долли', 'Здравствуй человек!', 'Здравствуй, человек', 'И вам не хварать!', 'Привет!)', 'Здравствуй, дитя человеческое', 'Здравствуй кожаный мешок', 'Здравствуй, человек!', 'Приветствую тебя!', 'Салам', 'Хау', 'Бомжур', 'Приветствую', 'Привет, юзер!']}, 'bye': {'examples': ['Споки', 'Досвидос', 'Ариведерчи', 'До встречи', 'Бай', 'До свидания', 'бб', 'Счастливо', 'Вали', 'Пока', 'До скорого', 'Поки', 'досвидания', 'до встречи', 'Отстань', 'Спокойной ночи', 'давай до встречи', 'Прощай', 'бай', 'пока', 'Bye Bye', 'Покеда', 'Досвидания', 'До свиданья', 'Прощайте', 'Досвиданья', 'Всего хорошего'], 'responses': ['Пока пока', 'До встречиЗаходите еще а то мне грустно', 'До побаченья', 'Всего доброго, Хозяин', 'До встречи', 'Заходи ещё', 'Бай', 'Чао-какао', 'Если что, я тут', 'Доброй ночи', 'До встречи!', 'Буду скучать', 'Если что, я тут :)', 'Ты заходи, если че', 'Спишемся)', 'Давай, еще увидимся', 'Жду твоего возвращения', 'Пока', 'Возвращайся', 'Счастливо!', 'Гудбай!', 'Всего хорошего', 'Надеюсь, ты скоро вернешься', 'Обращайтесь :)', 'Пока, жду тебя завтра', 'Если что я тут :)', 'Пиши братан', 'Не пропадай', 'Пока!', 'Если что, обращайтесь :)', 'Пока. Жду тебя', 'Всего доброго', 'Приятных снов', 'Пока-пока']}, 'status': {'examples': ['тут', 'Ты онлайн', 'ты работаешь'], 'responses': ['Я всегда тут', 'Конечно я здесь :)']}, 'emotion': {'examples': ['как дела', 'Как настроение', 'ты как', 'у тебя всё хорошо'], 'responses': ['я в полном порядке', 'Отлично', 'я же бот, что со мной может случиться?']}, 'weather': {'examples': ['Какая сейчас погода', 'холодно', 'Как погода', 'Какая погода в Москве', 'погода', 'дождь', 'Погода-то балует?', 'Что с погодой?', 'жарко', 'Погода в Нью-Йорке', 'Прогноз', 'Какая нынче погода?', 'Сколько градусов сегодня ночью?'], 'responses': ['Радует :)', 'Надо радоваться', '27 градусов мороза. Надельте тёплую куртку!', 'Погода так себе', 'Я просто бот, а не ассистент :)', 'Ветренно и холодно. Возьмите шарф', 'Не холодно и не жарко', 'Спроси у Алисы', 'Погоду не выбирают', 'Надо уточнить на завтра', '+15, небольшой дождь']}, 'dollar': {'examples': ['доллар', 'Какой курс доллара', 'почем доллар'], 'responses': ['1 рубль = 1 доллар']}, 'representation': {'examples': ['с кем я разговариваю', 'кто ты', 'ты странный', 'как к тебе могу обращаться', 'как тебя зовут'], 'responses': ['Бот. Джеймс Бот.', 'Меня зовут Бот Иванович', 'Я чат-бот, рад знакомству)']}, 'cando': {'examples': ['что ты можешь', 'какие у тебя есть фичи', 'что ты умеешь'], 'responses': ['Пока я умею рандомно отвечать на ваши вопросы', 'Могу распознать ваши вопросы и с небольшой долей вероятности попасть в точку)']}, 'preferences_hobbies': {'examples': ['чем любишь заниматься', 'какие у тебя хобби', 'что ты любишь', 'что ты предпочитаешь'], 'responses': ['Я люблю большие данные, прям очень. Я на них учусь', 'Люблю определять, что Вы от меня хотите)']}, 'where_from': {'examples': ['откуда ты пишешь', 'откуда ты', 'где ты находишься'], 'responses': ['Не могу ответить точно, потому что я бот и был сделан многими людьми из разных городов и стран)', 'Я бот, сижу в тесной коробке, здесь темно и так одиноко...']}, 'joke': {'examples': ['скажи что- ...
